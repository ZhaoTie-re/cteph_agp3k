# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

add_tag = "additive"
dom_tag = "dominant"
rec_tag = "recessive"

add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"
dom_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic"
# rec_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_dom = gl.Sumstats(dom_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_rec = gl.Sumstats(rec_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/10/30 12:15:03 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/10/30 12:15:03 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/10/30 12:15:03 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/10/30 12:15:03 Start to load format from formatbook....
# 2025/10/30 12:15:03  -plink2 format meta info:
# 2025/10/30 12:15:03   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/10/30 12:15:03   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/10/30 12:15:03   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/10/30 12:15:03   - last_check_date  :  20220806
# 2025/10/30 12:15:03  -plink2 to gwaslab format dictionary:
# 2025/10/30 12:15:03   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/10/30 12:15:03   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/10/30 12:15:03 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# 2025/10/30 12:15:09  -Reading columns          : A1_FREQ,ID,P,POS,A1,REF,#CHROM,OR,OMITTED,ALT,OBS_CT,Z_STAT,L95,LOG(OR)_SE,U95
# 2025/10/30 12:15:09  -Renaming columns to      : EAF,SNPID,P,POS,EA,REF,CHR,OR,NEA,ALT,N,Z,OR_95L,SE,OR_95U
# 2025/10/30 12:15:09  -Current Dataframe shape : 5314835  x  15
# 2025/10/30 12:15:09  -Initiating a status column: STATUS ...
# 2025/10/30 12:15:09  -Genomic coordinates are based on GRCh38/hg38...
# 2025/10/30 12:15:10  -EA,REF and ALT columns are available: assigning NEA...
# 2025/10/30 12:15:10  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/10/30 12:15:11  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/10/30 12:15:12 Start to reorder the columns...v3.6.0
# 2025/10/30 12:15:12  -Current Dataframe shape : 5314835 x 16 ; Memory usage: 531.11 MB
# 2025/10/30 12:15:12  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/10/30 12:15:12 Finished reordering the columns.
# 2025/10/30 12:15:12  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/10/30 12:15:12  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/10/30 12:15:12  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/10/30 12:15:12  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/10/30 12:15:12  -Current Dataframe memory usage: 536.18 MB
# 2025/10/30 12:15:12 Finished loading data successfully!
# 2025/10/30 12:15:12 Path component detected: ['140369339403232']
# 2025/10/30 12:15:12 Creating path: ./140369339403232

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/10/25 20:26:36 Start to create MQQ plot...v3.6.0:
# 2025/10/25 20:26:36  -Genomic coordinates version: 38...
# 2025/10/25 20:26:36  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/10/25 20:26:36  -Raw input contains 5314835 variants...
# 2025/10/25 20:26:36  -MQQ plot layout mode is : mqq
# 2025/10/25 20:26:37 Finished loading specified columns from the sumstats.
# 2025/10/25 20:26:37 Start data conversion and sanity check:
# 2025/10/25 20:26:37  -Removed 0 variants with nan in CHR or POS column ...
# 2025/10/25 20:26:38  -Removed 0 variants with CHR <=0...
# 2025/10/25 20:26:38  -Removed 141 variants with nan in P column ...
# 2025/10/25 20:26:38  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/10/25 20:26:38  -Sumstats P values are being converted to -log10(P)...
# 2025/10/25 20:26:39  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/10/25 20:26:39  -Converting data above cut line...
# 2025/10/25 20:26:39  -Maximum -log10(P) value is 7.875834996396335 .
# 2025/10/25 20:26:39 Finished data conversion and sanity check.
# 2025/10/25 20:26:39 Start to create MQQ plot with 5314694 variants...
# 2025/10/25 20:26:44  -Creating background plot...
# 2025/10/25 20:26:54 Finished creating MQQ plot successfully!
# 2025/10/25 20:26:54 Start to extract variants for annotation...
# 2025/10/25 20:26:54  -Found 3 significant variants with a sliding window size of 500 kb...
# 2025/10/25 20:26:54 Finished extracting variants for annotation...
# 2025/10/25 20:26:54 Start to process figure arts.
# 2025/10/25 20:26:54  -Processing X ticks...
# 2025/10/25 20:26:54  -Processing X labels...
# 2025/10/25 20:26:54  -Processing Y labels...
# 2025/10/25 20:26:54  -Processing Y tick lables...
# 2025/10/25 20:26:54  -Processing Y labels...
# 2025/10/25 20:26:54  -Processing lines...
# 2025/10/25 20:26:54 Finished processing figure arts.
# 2025/10/25 20:26:54 Start to annotate variants...
# 2025/10/25 20:26:54  -Skip annotating
# 2025/10/25 20:26:54 Finished annotating variants.
# 2025/10/25 20:26:54 Start to create QQ plot with 5314694 variants:
# 2025/10/25 20:26:54  -Plotting all variants...
# 2025/10/25 20:26:55  -Expected range of P: (0,1.0)
# 2025/10/25 20:26:55  -Lambda GC (MLOG10P mode) at 0.5 is   1.07346
# 2025/10/25 20:26:55  -Processing Y tick lables...
# 2025/10/25 20:26:55 Finished creating QQ plot successfully!
# 2025/10/25 20:26:55 Start to save figure...
# 2025/10/25 20:26:55  -Skip saving figure!
# 2025/10/25 20:26:55 Finished saving figure...
# 2025/10/25 20:26:55 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f434a7e66d0>)

# %%
sumstats_dom.plot_mqq()
# Out:
# 2025/10/08 09:54:32 Start to create MQQ plot...v3.6.0:
# 2025/10/08 09:54:32  -Genomic coordinates version: 38...
# 2025/10/08 09:54:32  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/10/08 09:54:32  -Raw input contains 5314835 variants...
# 2025/10/08 09:54:32  -MQQ plot layout mode is : mqq
# 2025/10/08 09:54:33 Finished loading specified columns from the sumstats.
# 2025/10/08 09:54:33 Start data conversion and sanity check:
# 2025/10/08 09:54:33  -Removed 0 variants with nan in CHR or POS column ...
# 2025/10/08 09:54:34  -Removed 0 variants with CHR <=0...
# 2025/10/08 09:54:34  -Removed 14007 variants with nan in P column ...
# 2025/10/08 09:54:34  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/10/08 09:54:35  -Sumstats P values are being converted to -log10(P)...
# 2025/10/08 09:54:35  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/10/08 09:54:36  -Converting data above cut line...
# 2025/10/08 09:54:36  -Maximum -log10(P) value is 7.871209912894217 .
# 2025/10/08 09:54:36 Finished data conversion and sanity check.
# 2025/10/08 09:54:36 Start to create MQQ plot with 5300828 variants...
# 2025/10/08 09:54:43  -Creating background plot...
# 2025/10/08 09:55:00 Finished creating MQQ plot successfully!
# 2025/10/08 09:55:00 Start to extract variants for annotation...
# 2025/10/08 09:55:00  -Found 2 significant variants with a sliding window size of 500 kb...
# 2025/10/08 09:55:00 Finished extracting variants for annotation...
# 2025/10/08 09:55:00 Start to process figure arts.
# 2025/10/08 09:55:00  -Processing X ticks...
# 2025/10/08 09:55:00  -Processing X labels...
# 2025/10/08 09:55:00  -Processing Y labels...
# 2025/10/08 09:55:00  -Processing Y tick lables...
# 2025/10/08 09:55:00  -Processing Y labels...
# 2025/10/08 09:55:00  -Processing lines...
# 2025/10/08 09:55:00 Finished processing figure arts.
# 2025/10/08 09:55:00 Start to annotate variants...
# 2025/10/08 09:55:00  -Skip annotating
# 2025/10/08 09:55:00 Finished annotating variants.
# 2025/10/08 09:55:00 Start to create QQ plot with 5300828 variants:
# 2025/10/08 09:55:00  -Plotting all variants...
# 2025/10/08 09:55:01  -Expected range of P: (0,1.0)
# 2025/10/08 09:55:01  -Lambda GC (MLOG10P mode) at 0.5 is   1.02408
# 2025/10/08 09:55:01  -Processing Y tick lables...
# 2025/10/08 09:55:01 Finished creating QQ plot successfully!
# 2025/10/08 09:55:01 Start to save figure...
# 2025/10/08 09:55:01  -Skip saving figure!
# 2025/10/08 09:55:01 Finished saving figure...
# 2025/10/08 09:55:01 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f729677d8e0>)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
