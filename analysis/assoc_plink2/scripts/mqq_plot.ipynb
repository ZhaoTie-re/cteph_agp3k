# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

add_tag = "additive"
dom_tag = "dominant"
rec_tag = "recessive"

add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"
dom_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic"
# rec_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_dom = gl.Sumstats(dom_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_rec = gl.Sumstats(rec_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/12/01 10:02:51 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/12/01 10:02:51 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/12/01 10:02:51 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/12/01 10:02:51 Start to load format from formatbook....
# 2025/12/01 10:02:51  -plink2 format meta info:
# 2025/12/01 10:02:51   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/12/01 10:02:51   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/12/01 10:02:51   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/12/01 10:02:51   - last_check_date  :  20220806
# 2025/12/01 10:02:51  -plink2 to gwaslab format dictionary:
# 2025/12/01 10:02:51   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/12/01 10:02:51   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/12/01 10:02:51 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# 2025/12/01 10:02:57  -Reading columns          : ID,P,OBS_CT,ALT,OMITTED,Z_STAT,REF,#CHROM,A1_FREQ,LOG(OR)_SE,L95,POS,A1,OR,U95
# 2025/12/01 10:02:57  -Renaming columns to      : SNPID,P,N,ALT,NEA,Z,REF,CHR,EAF,SE,OR_95L,POS,EA,OR,OR_95U
# 2025/12/01 10:02:57  -Current Dataframe shape : 5922126  x  15
# 2025/12/01 10:02:58  -Initiating a status column: STATUS ...
# 2025/12/01 10:02:58  -Genomic coordinates are based on GRCh38/hg38...
# 2025/12/01 10:02:58  -EA,REF and ALT columns are available: assigning NEA...
# 2025/12/01 10:02:58  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/12/01 10:02:59  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/12/01 10:03:00 Start to reorder the columns...v3.6.0
# 2025/12/01 10:03:00  -Current Dataframe shape : 5922126 x 16 ; Memory usage: 590.17 MB
# 2025/12/01 10:03:00  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/12/01 10:03:00 Finished reordering the columns.
# 2025/12/01 10:03:01  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/12/01 10:03:01  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/12/01 10:03:01  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/12/01 10:03:01  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/12/01 10:03:01  -Current Dataframe memory usage: 595.81 MB
# 2025/12/01 10:03:01 Finished loading data successfully!
# 2025/12/01 10:03:01 Path component detected: ['140434134250112']
# 2025/12/01 10:03:01 Creating path: ./140434134250112

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/12/01 10:03:04 Start to create MQQ plot...v3.6.0:
# 2025/12/01 10:03:04  -Genomic coordinates version: 38...
# 2025/12/01 10:03:04  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/12/01 10:03:04  -Raw input contains 5922126 variants...
# 2025/12/01 10:03:04  -MQQ plot layout mode is : mqq
# 2025/12/01 10:03:04 Finished loading specified columns from the sumstats.
# 2025/12/01 10:03:04 Start data conversion and sanity check:
# 2025/12/01 10:03:05  -Removed 0 variants with nan in CHR or POS column ...
# 2025/12/01 10:03:05  -Removed 0 variants with CHR <=0...
# 2025/12/01 10:03:06  -Removed 154 variants with nan in P column ...
# 2025/12/01 10:03:06  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/12/01 10:03:06  -Sumstats P values are being converted to -log10(P)...
# 2025/12/01 10:03:06  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/12/01 10:03:07  -Converting data above cut line...
# 2025/12/01 10:03:07  -Maximum -log10(P) value is 10.172015266464625 .
# 2025/12/01 10:03:07 Finished data conversion and sanity check.
# 2025/12/01 10:03:07 Start to create MQQ plot with 5921972 variants...
# 2025/12/01 10:03:12  -Creating background plot...
# 2025/12/01 10:03:25 Finished creating MQQ plot successfully!
# 2025/12/01 10:03:25 Start to extract variants for annotation...
# 2025/12/01 10:03:25  -Found 4 significant variants with a sliding window size of 500 kb...
# 2025/12/01 10:03:25 Finished extracting variants for annotation...
# 2025/12/01 10:03:25 Start to process figure arts.
# 2025/12/01 10:03:25  -Processing X ticks...
# 2025/12/01 10:03:25  -Processing X labels...
# 2025/12/01 10:03:25  -Processing Y labels...
# 2025/12/01 10:03:25  -Processing Y tick lables...
# 2025/12/01 10:03:25  -Processing Y labels...
# 2025/12/01 10:03:25  -Processing lines...
# 2025/12/01 10:03:25 Finished processing figure arts.
# 2025/12/01 10:03:25 Start to annotate variants...
# 2025/12/01 10:03:25  -Skip annotating
# 2025/12/01 10:03:25 Finished annotating variants.
# 2025/12/01 10:03:25 Start to create QQ plot with 5921972 variants:
# 2025/12/01 10:03:25  -Plotting all variants...
# 2025/12/01 10:03:26  -Expected range of P: (0,1.0)
# 2025/12/01 10:03:26  -Lambda GC (MLOG10P mode) at 0.5 is   1.09508
# 2025/12/01 10:03:26  -Processing Y tick lables...
# 2025/12/01 10:03:26 Finished creating QQ plot successfully!
# 2025/12/01 10:03:26 Start to save figure...
# 2025/12/01 10:03:26  -Skip saving figure!
# 2025/12/01 10:03:26 Finished saving figure...
# 2025/12/01 10:03:26 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7fb89e0d66d0>)

# %%
sumstats_add.data[sumstats_add.data['SNPID'] == 'chr17:13547000:T:C']
# Out:
#                       SNPID  CHR       POS EA NEA       EAF       SE        Z  \
# 4709828  chr17:13547000:T:C   17  13547000  C   T  0.043109  0.16341  4.85868
#
#                 P       OR   OR_95L   OR_95U     N   STATUS REF ALT
# 4709828  0.000001  2.21213  1.60589  3.04723  2946  3899999   T   C
