# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

add_tag = "additive"
dom_tag = "dominant"
rec_tag = "recessive"

add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"
dom_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic"
# rec_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_dom = gl.Sumstats(dom_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_rec = gl.Sumstats(rec_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2026/03/03 01:17:44 GWASLab v4.1.1 https://cloufield.github.io/gwaslab/
# 2026/03/03 01:17:44 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/03/03 01:17:44 Python version: 3.12.12 | packaged by conda-forge | (main, Jan 26 2026, 23:51:32) [GCC 14.3.0]
# 2026/03/03 01:17:44 Start to load format from formatbook....
# 2026/03/03 01:17:44  -plink2 format meta info:
# 2026/03/03 01:17:44   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2026/03/03 01:17:44   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2026/03/03 01:17:44   - format_version  : Alpha 3.3 final (3 Jun)
# 2026/03/03 01:17:44   - last_check_date  :  20220806
# 2026/03/03 01:17:44  -plink2 to gwaslab format dictionary:
# 2026/03/03 01:17:44   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2026/03/03 01:17:44   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2026/03/03 01:17:44  -Top 3 inferred source formats:
# 2026/03/03 01:17:44    1. vcf [DETECTED] (score: 999.000)
# 2026/03/03 01:17:44 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# 2026/03/03 01:17:52  -Reading columns          : ALT,Z_STAT,A1,OBS_CT,P,POS,REF,#CHROM,ID,LOG(OR)_SE,A1_FREQ,L95,OMITTED,U95,OR
# 2026/03/03 01:17:52  -Renaming columns to      : ALT,Z,EA,N,P,POS,REF,CHR,SNPID,SE,EAF,OR_95L,NEA,OR_95U,OR
# 2026/03/03 01:17:52  -Current Dataframe shape : 4597017  x  15
# 2026/03/03 01:17:52  -Initiating a status column: STATUS ...
# 2026/03/03 01:17:52  -Genomic coordinates are based on GRCh38/hg38...
# 2026/03/03 01:17:52  -EA,REF and ALT columns are available: assigning NEA...
# 2026/03/03 01:17:52  -For variants with EA == ALT : assigning REF to NEA ...
# 2026/03/03 01:17:53  -For variants with EA != ALT : assigning ALT to NEA ...
# 2026/03/03 01:17:54 Start to reorder the columns ...(v4.1.1)
# 2026/03/03 01:17:54  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,REF,ALT,EAF,SE,OR,OR_95U,OR_95L,Z,P,N
# 2026/03/03 01:17:54  -Time taken: 0.173s
# 2026/03/03 01:17:54 Finished reordering the columns.
# 2026/03/03 01:17:54  -Trying to convert datatype for CHR: string -> Int64...Success
# 2026/03/03 01:17:55  -Column  : SNPID  CHR   POS   EA       NEA      STATUS REF      ALT      EAF     SE      OR      OR_95U  OR_95L  Z       P       N
# 2026/03/03 01:17:55  -DType   : object Int64 int64 category category int64  category category float64 float64 float64 float64 float64 float64 float64 int64
# 2026/03/03 01:17:55  -Verified: T      T     T     T        T        T      T        T        T       T       T       T       T       T       T       T
# 2026/03/03 01:17:55  -Current Dataframe memory usage: 462.30 MB
# 2026/03/03 01:17:55 Finished loading data successfully!

# %%
sumstats_add.plot_mqq()
# Out:
# 2026/03/03 01:17:57 Configured plot style for plot_mqq:mqq
# 2026/03/03 01:17:57 Starting Manhattan-QQ plot creation (Version v4.1.1)
# 2026/03/03 01:17:57  -Genomic coordinates are based on GRCh38/hg38...
# 2026/03/03 01:17:57  - Genomic coordinates version: 38 ...
# 2026/03/03 01:17:57  - Genome-wide significance level to plot is set to 5e-08 ...
# 2026/03/03 01:17:57  - Input sumstats contains 4597017 variants...
# 2026/03/03 01:17:57  - Manhattan-QQ plot layout mode selected: mqq
# 2026/03/03 01:17:58 Finished loading specified columns from the statistics
# 2026/03/03 01:17:58 Start data conversion and sanity check:
# 2026/03/03 01:17:59  -Removed 121 variants with nan in P column ...
# 2026/03/03 01:17:59  -Sumstats P values are being converted to -log10(P)...
# 2026/03/03 01:18:00  -Converting data above cut line...
# 2026/03/03 01:18:00  -Maximum -log10(P) value is 7.804598550479781 .
# 2026/03/03 01:18:00 Finished data conversion and sanity check.
# 2026/03/03 01:18:00 Start to create Manhattan-QQ plot with 4596896 variants...
# 2026/03/03 01:18:03  -Creating background plot...
# 2026/03/03 01:18:14 Finished creating Manhattan-QQ plot successfully
# 2026/03/03 01:18:14 Start to extract variants for annotation...
# 2026/03/03 01:18:14  -Found 1 lead variants with a sliding window size of 500 kb (scaled threshold: 7.301029995663981)...
# 2026/03/03 01:18:14 Finished extracting variants for annotation...
# 2026/03/03 01:18:14 Start to create QQ plot with 4596896 variants:
# 2026/03/03 01:18:14  -Plotting all variants...
# 2026/03/03 01:18:15  -Expected range of P: (0,1.0)
# 2026/03/03 01:18:15  -Lambda GC (MLOG10P mode) at 0.5 is   1.07028
# 2026/03/03 01:18:15 Finished creating QQ plot successfully!
# 2026/03/03 01:18:16 Finished creating plot successfully

# %%
sumstats_add.data[sumstats_add.data['SNPID'] == 'chr17:13547000:T:C']
# Out:
#                       SNPID  CHR       POS EA NEA       EAF       SE        Z  \
# 4709828  chr17:13547000:T:C   17  13547000  C   T  0.043109  0.16341  4.85868
#
#                 P       OR   OR_95L   OR_95U     N   STATUS REF ALT
# 4709828  0.000001  2.21213  1.60589  3.04723  2946  3899999   T   C
