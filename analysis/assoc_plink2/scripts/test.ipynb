# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

add_tag = "additive"
dom_tag = "dominant"
rec_tag = "recessive"

add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"
# dom_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic"
# rec_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_dom = gl.Sumstats(dom_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_rec = gl.Sumstats(rec_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/09/29 21:31:41 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/09/29 21:31:41 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/09/29 21:31:41 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/09/29 21:31:41 Start to load format from formatbook....
# 2025/09/29 21:31:41  -plink2 format meta info:
# 2025/09/29 21:31:41   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/09/29 21:31:41   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/09/29 21:31:41   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/09/29 21:31:41   - last_check_date  :  20220806
# 2025/09/29 21:31:41  -plink2 to gwaslab format dictionary:
# 2025/09/29 21:31:41   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/09/29 21:31:41   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/09/29 21:31:41 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# 2025/09/29 21:31:47  -Reading columns          : POS,A1,REF,Z_STAT,OMITTED,OBS_CT,A1_FREQ,L95,OR,LOG(OR)_SE,P,U95,ID,ALT,#CHROM
# 2025/09/29 21:31:47  -Renaming columns to      : POS,EA,REF,Z,NEA,N,EAF,OR_95L,OR,SE,P,OR_95U,SNPID,ALT,CHR
# 2025/09/29 21:31:47  -Current Dataframe shape : 5161831  x  15
# 2025/09/29 21:31:47  -Initiating a status column: STATUS ...
# 2025/09/29 21:31:47  -Genomic coordinates are based on GRCh38/hg38...
# 2025/09/29 21:31:47  -EA,REF and ALT columns are available: assigning NEA...
# 2025/09/29 21:31:47  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/09/29 21:31:48  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/09/29 21:31:49 Start to reorder the columns...v3.6.0
# 2025/09/29 21:31:49  -Current Dataframe shape : 5161831 x 16 ; Memory usage: 516.49 MB
# 2025/09/29 21:31:49  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/09/29 21:31:49 Finished reordering the columns.
# 2025/09/29 21:31:49  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/09/29 21:31:50  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/09/29 21:31:50  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/09/29 21:31:50  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/09/29 21:31:50  -Current Dataframe memory usage: 521.41 MB
# 2025/09/29 21:31:50 Finished loading data successfully!
# 2025/09/29 21:31:50 Path component detected: ['139724853522976']
# 2025/09/29 21:31:50 Creating path: ./139724853522976

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/09/29 21:31:50 Start to create MQQ plot...v3.6.0:
# 2025/09/29 21:31:50  -Genomic coordinates version: 38...
# 2025/09/29 21:31:50  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/09/29 21:31:50  -Raw input contains 5161831 variants...
# 2025/09/29 21:31:50  -MQQ plot layout mode is : mqq
# 2025/09/29 21:31:50 Finished loading specified columns from the sumstats.
# 2025/09/29 21:31:50 Start data conversion and sanity check:
# 2025/09/29 21:31:51  -Removed 0 variants with nan in CHR or POS column ...
# 2025/09/29 21:31:51  -Removed 0 variants with CHR <=0...
# 2025/09/29 21:31:51  -Removed 148 variants with nan in P column ...
# 2025/09/29 21:31:52  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/09/29 21:31:52  -Sumstats P values are being converted to -log10(P)...
# 2025/09/29 21:31:52  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/09/29 21:31:53  -Converting data above cut line...
# 2025/09/29 21:31:53  -Maximum -log10(P) value is 7.817034981363827 .
# 2025/09/29 21:31:53 Finished data conversion and sanity check.
# 2025/09/29 21:31:53 Start to create MQQ plot with 5161683 variants...
# 2025/09/29 21:31:57  -Creating background plot...
# 2025/09/29 21:32:07 Finished creating MQQ plot successfully!
# 2025/09/29 21:32:07 Start to extract variants for annotation...
# 2025/09/29 21:32:07  -Found 4 significant variants with a sliding window size of 500 kb...
# 2025/09/29 21:32:07 Finished extracting variants for annotation...
# 2025/09/29 21:32:07 Start to process figure arts.
# 2025/09/29 21:32:07  -Processing X ticks...
# 2025/09/29 21:32:07  -Processing X labels...
# 2025/09/29 21:32:07  -Processing Y labels...
# 2025/09/29 21:32:07  -Processing Y tick lables...
# 2025/09/29 21:32:07  -Processing Y labels...
# 2025/09/29 21:32:07  -Processing lines...
# 2025/09/29 21:32:07 Finished processing figure arts.
# 2025/09/29 21:32:07 Start to annotate variants...
# 2025/09/29 21:32:07  -Skip annotating
# 2025/09/29 21:32:07 Finished annotating variants.
# 2025/09/29 21:32:07 Start to create QQ plot with 5161683 variants:
# 2025/09/29 21:32:07  -Plotting all variants...
# 2025/09/29 21:32:08  -Expected range of P: (0,1.0)
# 2025/09/29 21:32:08  -Lambda GC (MLOG10P mode) at 0.5 is   1.07136
# 2025/09/29 21:32:08  -Processing Y tick lables...
# 2025/09/29 21:32:08 Finished creating QQ plot successfully!
# 2025/09/29 21:32:08 Start to save figure...
# 2025/09/29 21:32:08  -Skip saving figure!
# 2025/09/29 21:32:08 Finished saving figure...
# 2025/09/29 21:32:08 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f1379b8a040>)
