# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

add_tag = "additive"
dom_tag = "dominant"
rec_tag = "recessive"

add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"
# dom_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic"
# rec_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_dom = gl.Sumstats(dom_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# sumstats_rec = gl.Sumstats(rec_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/09/04 14:04:31 GWASLab v3.6.5 https://cloufield.github.io/gwaslab/
# 2025/09/04 14:04:31 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/09/04 14:04:31 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/09/04 14:04:31 Start to load format from formatbook....
# 2025/09/04 14:04:31  -plink2 format meta info:
# 2025/09/04 14:04:31   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/09/04 14:04:31   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/09/04 14:04:31   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/09/04 14:04:31   - last_check_date  :  20220806
# 2025/09/04 14:04:31  -plink2 to gwaslab format dictionary:
# 2025/09/04 14:04:31   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/09/04 14:04:31   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/09/04 14:04:31 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# 2025/09/04 14:04:41  -Reading columns          : ID,REF,OR,OBS_CT,#CHROM,OMITTED,POS,LOG(OR)_SE,Z_STAT,P,L95,ALT,U95,A1,A1_FREQ
# 2025/09/04 14:04:41  -Renaming columns to      : SNPID,REF,OR,N,CHR,NEA,POS,SE,Z,P,OR_95L,ALT,OR_95U,EA,EAF
# 2025/09/04 14:04:41  -Current Dataframe shape : 5217024  x  15
# 2025/09/04 14:04:41  -Initiating a status column: STATUS ...
# 2025/09/04 14:04:41  -Genomic coordinates are based on GRCh38/hg38...
# 2025/09/04 14:04:42  -EA,REF and ALT columns are available: assigning NEA...
# 2025/09/04 14:04:42  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/09/04 14:04:43  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/09/04 14:04:44 Start to reorder the columns...v3.6.5
# 2025/09/04 14:04:44  -Current Dataframe shape : 5217024 x 16 ; Memory usage: 520.99 MB
# 2025/09/04 14:04:44  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/09/04 14:04:45 Finished reordering the columns.
# 2025/09/04 14:04:45  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/09/04 14:04:45  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/09/04 14:04:45  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/09/04 14:04:45  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/09/04 14:04:45  -Current Dataframe memory usage: 525.97 MB
# 2025/09/04 14:04:45 Finished loading data successfully!

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/09/04 14:04:45 Start to create MQQ plot...v3.6.5:
# 2025/09/04 14:04:45  -Genomic coordinates version: 38...
# 2025/09/04 14:04:45  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/09/04 14:04:45  -Raw input contains 5217024 variants...
# 2025/09/04 14:04:45  -MQQ plot layout mode is : mqq
# 2025/09/04 14:04:46 Finished loading specified columns from the sumstats.
# 2025/09/04 14:04:46 Start data conversion and sanity check:
# 2025/09/04 14:04:46  -Removed 0 variants with nan in CHR or POS column ...
# 2025/09/04 14:04:47  -Removed 0 variants with CHR <=0...
# 2025/09/04 14:04:47  -Removed 130 variants with nan in P column ...
# 2025/09/04 14:04:47  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/09/04 14:04:48  -Sumstats P values are being converted to -log10(P)...
# 2025/09/04 14:04:48  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/09/04 14:04:49  -Converting data above cut line...
# 2025/09/04 14:04:49  -Maximum -log10(P) value is 10.033596830262566 .
# 2025/09/04 14:04:49 Finished data conversion and sanity check.
# 2025/09/04 14:04:49 Start to create MQQ plot with 5216894 variants...
# 2025/09/04 14:04:53  -Creating background plot...
# 2025/09/04 14:05:05 Finished creating MQQ plot successfully!
# 2025/09/04 14:05:05 Start to extract variants for annotation...
# 2025/09/04 14:05:05  -Found 4 significant variants with a sliding window size of 500 kb...
# 2025/09/04 14:05:05 Finished extracting variants for annotation...
# 2025/09/04 14:05:05 Start to process figure arts.
# 2025/09/04 14:05:05  -Processing X ticks...
# 2025/09/04 14:05:05  -Processing X labels...
# 2025/09/04 14:05:05  -Processing Y labels...
# 2025/09/04 14:05:05  -Processing Y tick lables...
# 2025/09/04 14:05:05  -Processing Y labels...
# 2025/09/04 14:05:05  -Processing lines...
# 2025/09/04 14:05:05 Finished processing figure arts.
# 2025/09/04 14:05:05 Start to annotate variants...
# 2025/09/04 14:05:05  -Skip annotating
# 2025/09/04 14:05:05 Finished annotating variants.
# 2025/09/04 14:05:05 Start to create QQ plot with 5216894 variants:
# 2025/09/04 14:05:05  -Plotting all variants...
# 2025/09/04 14:05:06  -Expected range of P: (0,1.0)
# 2025/09/04 14:05:06  -Lambda GC (MLOG10P mode) at 0.5 is   1.09001
# 2025/09/04 14:05:06  -Processing Y tick lables...
# 2025/09/04 14:05:06 Finished creating QQ plot successfully!
# 2025/09/04 14:05:06 Start to save figure...
# 2025/09/04 14:05:06  -Skip saving figure!
# 2025/09/04 14:05:06 Finished saving figure...
# 2025/09/04 14:05:06 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f9427a2fe20>)
