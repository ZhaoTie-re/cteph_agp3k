# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

add_tag = "additive"
dom_tag = "dominant"
rec_tag = "recessive"

add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"
dom_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic"
rec_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
sumstats_dom = gl.Sumstats(dom_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
sumstats_rec = gl.Sumstats(rec_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/06/28 13:07:59 GWASLab v3.6.5 https://cloufield.github.io/gwaslab/
# 2025/06/28 13:07:59 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/06/28 13:07:59 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/06/28 13:07:59 Start to load format from formatbook....
# 2025/06/28 13:07:59  -plink2 format meta info:
# 2025/06/28 13:07:59   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/06/28 13:07:59   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/06/28 13:07:59   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/06/28 13:07:59   - last_check_date  :  20220806
# 2025/06/28 13:07:59  -plink2 to gwaslab format dictionary:
# 2025/06/28 13:07:59   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/06/28 13:07:59   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/06/28 13:07:59 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# 2025/06/28 13:08:08  -Reading columns          : Z_STAT,U95,A1_FREQ,POS,ALT,OR,REF,A1,L95,LOG(OR)_SE,OMITTED,P,ID,#CHROM,OBS_CT
# 2025/06/28 13:08:08  -Renaming columns to      : Z,OR_95U,EAF,POS,ALT,OR,REF,EA,OR_95L,SE,NEA,P,SNPID,CHR,N
# 2025/06/28 13:08:08  -Current Dataframe shape : 6022542  x  15
# 2025/06/28 13:08:08  -Initiating a status column: STATUS ...
# 2025/06/28 13:08:08  -Genomic coordinates are based on GRCh38/hg38...
# 2025/06/28 13:08:09  -EA,REF and ALT columns are available: assigning NEA...
# 2025/06/28 13:08:10  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/06/28 13:08:10  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/06/28 13:08:12 Start to reorder the columns...v3.6.5
# 2025/06/28 13:08:12  -Current Dataframe shape : 6022542 x 16 ; Memory usage: 599.53 MB
# 2025/06/28 13:08:12  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/06/28 13:08:12 Finished reordering the columns.
# 2025/06/28 13:08:12  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/06/28 13:08:13  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/06/28 13:08:13  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/06/28 13:08:13  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/06/28 13:08:13  -Current Dataframe memory usage: 605.27 MB
# 2025/06/28 13:08:13 Finished loading data successfully!
# 2025/06/28 13:08:13 GWASLab v3.6.5 https://cloufield.github.io/gwaslab/
# 2025/06/28 13:08:13 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/06/28 13:08:13 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/06/28 13:08:13 Start to load format from formatbook....
# 2025/06/28 13:08:13  -plink2 format meta info:
# 2025/06/28 13:08:13   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/06/28 13:08:13   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/06/28 13:08:13   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/06/28 13:08:13   - last_check_date  :  20220806
# 2025/06/28 13:08:13  -plink2 to gwaslab format dictionary:
# 2025/06/28 13:08:13   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/06/28 13:08:13   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/06/28 13:08:13 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/dominant/cteph_agp3k.sex.10pc.dominant.PHENO1.glm.logistic
# 2025/06/28 13:08:23  -Reading columns          : Z_STAT,U95,A1_FREQ,POS,ALT,OR,REF,A1,L95,LOG(OR)_SE,OMITTED,P,ID,#CHROM,OBS_CT
# 2025/06/28 13:08:23  -Renaming columns to      : Z,OR_95U,EAF,POS,ALT,OR,REF,EA,OR_95L,SE,NEA,P,SNPID,CHR,N
# 2025/06/28 13:08:23  -Current Dataframe shape : 6022542  x  15
# 2025/06/28 13:08:23  -Initiating a status column: STATUS ...
# 2025/06/28 13:08:23  -Genomic coordinates are based on GRCh38/hg38...
# 2025/06/28 13:08:24  -EA,REF and ALT columns are available: assigning NEA...
# 2025/06/28 13:08:25  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/06/28 13:08:25  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/06/28 13:08:27 Start to reorder the columns...v3.6.5
# 2025/06/28 13:08:27  -Current Dataframe shape : 6022542 x 16 ; Memory usage: 599.53 MB
# 2025/06/28 13:08:27  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/06/28 13:08:27 Finished reordering the columns.
# 2025/06/28 13:08:27  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/06/28 13:08:28  -Trying to convert datatype for OR_95U: object -> float64...float64
# 2025/06/28 13:08:28  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/06/28 13:08:28  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/06/28 13:08:28  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/06/28 13:08:28  -Current Dataframe memory usage: 605.27 MB
# 2025/06/28 13:08:28 Finished loading data successfully!
# /home/b/b37974/anaconda3/envs/gwaslab/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:133: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=True)
# 2025/06/28 13:08:29 GWASLab v3.6.5 https://cloufield.github.io/gwaslab/
# 2025/06/28 13:08:29 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/06/28 13:08:29 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/06/28 13:08:29 Start to load format from formatbook....
# 2025/06/28 13:08:29  -plink2 format meta info:
# 2025/06/28 13:08:29   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/06/28 13:08:29   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/06/28 13:08:29   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/06/28 13:08:29   - last_check_date  :  20220806
# 2025/06/28 13:08:29  -plink2 to gwaslab format dictionary:
# 2025/06/28 13:08:29   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/06/28 13:08:29   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/06/28 13:08:29 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/recessive/cteph_agp3k.sex.10pc.recessive.PHENO1.glm.logistic
# 2025/06/28 13:08:38  -Reading columns          : Z_STAT,U95,A1_FREQ,POS,ALT,OR,REF,A1,L95,LOG(OR)_SE,OMITTED,P,ID,#CHROM,OBS_CT
# 2025/06/28 13:08:38  -Renaming columns to      : Z,OR_95U,EAF,POS,ALT,OR,REF,EA,OR_95L,SE,NEA,P,SNPID,CHR,N
# 2025/06/28 13:08:38  -Current Dataframe shape : 6022542  x  15
# 2025/06/28 13:08:39  -Initiating a status column: STATUS ...
# 2025/06/28 13:08:39  -Genomic coordinates are based on GRCh38/hg38...
# 2025/06/28 13:08:39  -EA,REF and ALT columns are available: assigning NEA...
# 2025/06/28 13:08:40  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/06/28 13:08:41  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/06/28 13:08:42 Start to reorder the columns...v3.6.5
# 2025/06/28 13:08:42  -Current Dataframe shape : 6022542 x 16 ; Memory usage: 599.53 MB
# 2025/06/28 13:08:42  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/06/28 13:08:42 Finished reordering the columns.
# 2025/06/28 13:08:43  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/06/28 13:08:43  -Trying to convert datatype for OR_95U: object -> float64...float64
# 2025/06/28 13:08:44  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/06/28 13:08:44  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/06/28 13:08:44  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/06/28 13:08:44  -Current Dataframe memory usage: 605.27 MB
# 2025/06/28 13:08:44 Finished loading data successfully!
# /home/b/b37974/anaconda3/envs/gwaslab/lib/python3.9/site-packages/pandas/core/dtypes/astype.py:133: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=True)

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/06/28 13:09:23 Start to create MQQ plot...v3.6.5:
# 2025/06/28 13:09:23  -Genomic coordinates version: 38...
# 2025/06/28 13:09:23  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/06/28 13:09:23  -Raw input contains 6022542 variants...
# 2025/06/28 13:09:23  -MQQ plot layout mode is : mqq
# 2025/06/28 13:09:24 Finished loading specified columns from the sumstats.
# 2025/06/28 13:09:24 Start data conversion and sanity check:
# 2025/06/28 13:09:24  -Removed 0 variants with nan in CHR or POS column ...
# 2025/06/28 13:09:24  -Removed 0 variants with CHR <=0...
# 2025/06/28 13:09:25  -Removed 301 variants with nan in P column ...
# 2025/06/28 13:09:25  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/06/28 13:09:25  -Sumstats P values are being converted to -log10(P)...
# 2025/06/28 13:09:25  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/06/28 13:09:26  -Converting data above cut line...
# 2025/06/28 13:09:26  -Maximum -log10(P) value is 10.497481387357105 .
# 2025/06/28 13:09:26 Finished data conversion and sanity check.
# 2025/06/28 13:09:26 Start to create MQQ plot with 6022241 variants...
# 2025/06/28 13:09:31  -Creating background plot...
# 2025/06/28 13:09:44 Finished creating MQQ plot successfully!
# 2025/06/28 13:09:44 Start to extract variants for annotation...
# 2025/06/28 13:09:44  -Found 9 significant variants with a sliding window size of 500 kb...
# 2025/06/28 13:09:44 Finished extracting variants for annotation...
# 2025/06/28 13:09:44 Start to process figure arts.
# 2025/06/28 13:09:44  -Processing X ticks...
# 2025/06/28 13:09:44  -Processing X labels...
# 2025/06/28 13:09:44  -Processing Y labels...
# 2025/06/28 13:09:44  -Processing Y tick lables...
# 2025/06/28 13:09:44  -Processing Y labels...
# 2025/06/28 13:09:44  -Processing lines...
# 2025/06/28 13:09:44 Finished processing figure arts.
# 2025/06/28 13:09:44 Start to annotate variants...
# 2025/06/28 13:09:44  -Skip annotating
# 2025/06/28 13:09:44 Finished annotating variants.
# 2025/06/28 13:09:44 Start to create QQ plot with 6022241 variants:
# 2025/06/28 13:09:44  -Plotting all variants...
# 2025/06/28 13:09:45  -Expected range of P: (0,1.0)
# 2025/06/28 13:09:45  -Lambda GC (MLOG10P mode) at 0.5 is   1.09253
# 2025/06/28 13:09:45  -Processing Y tick lables...
# 2025/06/28 13:09:45 Finished creating QQ plot successfully!
# 2025/06/28 13:09:45 Start to save figure...
# 2025/06/28 13:09:45  -Skip saving figure!
# 2025/06/28 13:09:45 Finished saving figure...
# 2025/06/28 13:09:45 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f21aefb8610>)
