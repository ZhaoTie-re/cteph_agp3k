# %%
import sys, importlib
MODULE_DIR = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_rvtest/scripts"
if MODULE_DIR not in sys.path:
    sys.path.insert(0, MODULE_DIR)

import rvtest_prepare_tools
importlib.reload(rvtest_prepare_tools)
# Out:
# <module 'rvtest_prepare_tools' from '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_rvtest/scripts/rvtest_prepare_tools.py'>

# %%
from rvtest_prepare_tools import plink_to_vcf_raw

vcf_path = plink_to_vcf_raw(
    bed_prefix = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/19.tommo_panel_filter/cteph_agp3k.lowfreq_common",
    threads = 8, 
    snps_only_just_acgt = True,
)
# Out:
# [信息] 正在用 plink 导出 bgzip VCF（样本名为 IID）…
# [信息] 正在用 bcftools 为初始 .vcf.gz 建立 tbi 索引…
# [信息] 检测到 rename_chr 映射文件，执行染色体重命名：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/info/rename_chr.txt
# [信息] 正在为重命名后的 VCF 建立 tbi 索引…
# [信息] 正在用 bcftools norm 进行规范化（--multiallelics -any, --check-ref s）…
# [信息] 正在用 tabix 为规范化后的 .vcf.gz 建立 tbi 索引…
# [完成] 生成规范化后的压缩 VCF：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_rvtest/scripts/cteph_agp3k.lowfreq_common.snp.norm.vcf.gz
# [完成] 生成规范化后的索引：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_rvtest/scripts/cteph_agp3k.lowfreq_common.snp.norm.vcf.gz.tbi

# %%
# Out:
# /home/b/b37974/anaconda3/envs/cteph_geno_pro/bin/R
