# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

saige_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_saige.test/results/01.saige_sparse_grm/02.saige_assoc/cteph_agp3k.saige.assoc.txt"

# %%
sumstats_saige = gl.Sumstats(saige_path, fmt="saige", snpid="MarkerID", build='38', ea='Allele2', nea='Allele1')
# Out:
# 2026/02/24 15:29:22 GWASLab v4.1.1 https://cloufield.github.io/gwaslab/
# 2026/02/24 15:29:22 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/02/24 15:29:22 Python version: 3.12.12 | packaged by conda-forge | (main, Jan 26 2026, 23:51:32) [GCC 14.3.0]
# 2026/02/24 15:29:22 Start to load format from formatbook....
# 2026/02/24 15:29:22  -saige format meta info:
# 2026/02/24 15:29:22   - format_name  : saige
# 2026/02/24 15:29:22   - format_source  : https://saigegit.github.io//SAIGE-doc/docs/single_step2.html
# 2026/02/24 15:29:22   - format_version  : v1.1.3
# 2026/02/24 15:29:22   - last_check_date  :  20220806
# 2026/02/24 15:29:22  -saige to gwaslab format dictionary:
# 2026/02/24 15:29:22   - saige keys: SNPID,CHR,POS,Allele1,Allele2,AF_Allele2,N,BETA,SE,p.value,imputationInfo
# 2026/02/24 15:29:22   - gwaslab values: SNPID,CHR,POS,NEA,EA,EAF,N,BETA,SE,P,INFO
# 2026/02/24 15:29:22  -Top 3 inferred source formats:
# ...

# %%
sumstats_saige.plot_mqq()
# Out:
# 2026/02/24 15:29:56 Configured plot style for plot_mqq:mqq
# 2026/02/24 15:29:56 Starting Manhattan-QQ plot creation (Version v4.1.1)
# 2026/02/24 15:29:56  -Genomic coordinates are based on GRCh38/hg38...
# 2026/02/24 15:29:56  - Genomic coordinates version: 38 ...
# 2026/02/24 15:29:56  - Genome-wide significance level to plot is set to 5e-08 ...
# 2026/02/24 15:29:56  - Input sumstats contains 4597017 variants...
# 2026/02/24 15:29:56  - Manhattan-QQ plot layout mode selected: mqq
# 2026/02/24 15:29:57 Finished loading specified columns from the statistics
# 2026/02/24 15:29:57 Start data conversion and sanity check:
# 2026/02/24 15:29:58  -Sumstats P values are being converted to -log10(P)...
# 2026/02/24 15:29:59  -Converting data above cut line...
# 2026/02/24 15:29:59  -Maximum -log10(P) value is 7.552139135717928 .
# 2026/02/24 15:29:59 Finished data conversion and sanity check.
# 2026/02/24 15:29:59 Start to create Manhattan-QQ plot with 4597017 variants...
# ...
