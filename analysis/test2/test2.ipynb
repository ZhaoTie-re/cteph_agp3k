# %%
import gwaslab as gl
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')

sex_10pcs_sumstats = gl.Sumstats("/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/test2/cteph_agp3k.sex_pcs.PHENO1.glm.logistic",fmt="plink2")
sex_10pcs_sumstats.plot_mqq(anno=True, sig_level_lead=5e-8, additional_line_color="blue")
# Out:
# 2025/05/30 10:46:11 GWASLab v3.5.5 https://cloufield.github.io/gwaslab/
# 2025/05/30 10:46:11 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/05/30 10:46:11 Start to load format from formatbook....
# 2025/05/30 10:46:11  -plink2 format meta info:
# 2025/05/30 10:46:11   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/05/30 10:46:11   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/05/30 10:46:11   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/05/30 10:46:11   - last_check_date  :  20220806
# 2025/05/30 10:46:11  -plink2 to gwaslab format dictionary:
# 2025/05/30 10:46:11   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/05/30 10:46:11   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# ...
