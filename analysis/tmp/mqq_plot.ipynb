# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8
add_tag = "additive"
add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/tmp/cteph_agp3k_rm_amb.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/11/17 19:27:38 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/11/17 19:27:38 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/11/17 19:27:38 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/11/17 19:27:38 Start to load format from formatbook....
# 2025/11/17 19:27:38  -plink2 format meta info:
# 2025/11/17 19:27:38   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/11/17 19:27:38   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/11/17 19:27:38   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/11/17 19:27:38   - last_check_date  :  20220806
# 2025/11/17 19:27:38  -plink2 to gwaslab format dictionary:
# 2025/11/17 19:27:38   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/11/17 19:27:38   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/11/17 19:27:38 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/tmp/cteph_agp3k_rm_amb.PHENO1.glm.logistic
# 2025/11/17 19:27:47  -Reading columns          : A1_FREQ,U95,Z_STAT,P,REF,#CHROM,OR,ID,A1,OBS_CT,L95,LOG(OR)_SE,ALT,POS,OMITTED
# 2025/11/17 19:27:47  -Renaming columns to      : EAF,OR_95U,Z,P,REF,CHR,OR,SNPID,EA,N,OR_95L,SE,ALT,POS,NEA
# 2025/11/17 19:27:47  -Current Dataframe shape : 5314835  x  15
# 2025/11/17 19:27:47  -Initiating a status column: STATUS ...
# 2025/11/17 19:27:47  -Genomic coordinates are based on GRCh38/hg38...
# 2025/11/17 19:27:48  -EA,REF and ALT columns are available: assigning NEA...
# 2025/11/17 19:27:48  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/11/17 19:27:49  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/11/17 19:27:50 Start to reorder the columns...v3.6.0
# 2025/11/17 19:27:50  -Current Dataframe shape : 5314835 x 16 ; Memory usage: 531.11 MB
# 2025/11/17 19:27:50  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/11/17 19:27:50 Finished reordering the columns.
# 2025/11/17 19:27:50  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/11/17 19:27:51  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/11/17 19:27:51  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/11/17 19:27:51  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/11/17 19:27:51  -Current Dataframe memory usage: 536.18 MB
# 2025/11/17 19:27:51 Finished loading data successfully!
# 2025/11/17 19:27:51 Path component detected: ['140685795139696']
# 2025/11/17 19:27:51 Creating path: ./140685795139696

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/11/17 19:27:56 Start to create MQQ plot...v3.6.0:
# 2025/11/17 19:27:56  -Genomic coordinates version: 38...
# 2025/11/17 19:27:56  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/11/17 19:27:56  -Raw input contains 5314835 variants...
# 2025/11/17 19:27:56  -MQQ plot layout mode is : mqq
# 2025/11/17 19:27:57 Finished loading specified columns from the sumstats.
# 2025/11/17 19:27:57 Start data conversion and sanity check:
# 2025/11/17 19:27:57  -Removed 0 variants with nan in CHR or POS column ...
# 2025/11/17 19:27:57  -Removed 0 variants with CHR <=0...
# 2025/11/17 19:27:58  -Removed 145 variants with nan in P column ...
# 2025/11/17 19:27:58  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/11/17 19:27:58  -Sumstats P values are being converted to -log10(P)...
# 2025/11/17 19:27:59  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/11/17 19:27:59  -Converting data above cut line...
# 2025/11/17 19:27:59  -Maximum -log10(P) value is 7.880879436315352 .
# 2025/11/17 19:27:59 Finished data conversion and sanity check.
# 2025/11/17 19:27:59 Start to create MQQ plot with 5314690 variants...
# 2025/11/17 19:28:04  -Creating background plot...
# 2025/11/17 19:28:16 Finished creating MQQ plot successfully!
# 2025/11/17 19:28:16 Start to extract variants for annotation...
# 2025/11/17 19:28:16  -Found 3 significant variants with a sliding window size of 500 kb...
# 2025/11/17 19:28:16 Finished extracting variants for annotation...
# 2025/11/17 19:28:16 Start to process figure arts.
# 2025/11/17 19:28:16  -Processing X ticks...
# 2025/11/17 19:28:16  -Processing X labels...
# 2025/11/17 19:28:16  -Processing Y labels...
# 2025/11/17 19:28:16  -Processing Y tick lables...
# 2025/11/17 19:28:16  -Processing Y labels...
# 2025/11/17 19:28:16  -Processing lines...
# 2025/11/17 19:28:16 Finished processing figure arts.
# 2025/11/17 19:28:16 Start to annotate variants...
# 2025/11/17 19:28:16  -Skip annotating
# 2025/11/17 19:28:16 Finished annotating variants.
# 2025/11/17 19:28:16 Start to create QQ plot with 5314690 variants:
# 2025/11/17 19:28:16  -Plotting all variants...
# 2025/11/17 19:28:17  -Expected range of P: (0,1.0)
# 2025/11/17 19:28:17  -Lambda GC (MLOG10P mode) at 0.5 is   1.07214
# 2025/11/17 19:28:17  -Processing Y tick lables...
# 2025/11/17 19:28:17 Finished creating QQ plot successfully!
# 2025/11/17 19:28:17 Start to save figure...
# 2025/11/17 19:28:17  -Skip saving figure!
# 2025/11/17 19:28:17 Finished saving figure...
# 2025/11/17 19:28:17 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7ff33639c4f0>)

# %%
sumstats_add.data[sumstats_add.data['SNPID'] == 'chr17:13547000:T:C']
# Out:
#                       SNPID  CHR       POS EA NEA       EAF       SE        Z  \
# 4709828  chr17:13547000:T:C   17  13547000  C   T  0.043109  0.16341  4.85868
#
#                 P       OR   OR_95L   OR_95U     N   STATUS REF ALT
# 4709828  0.000001  2.21213  1.60589  3.04723  2946  3899999   T   C
