# %%
import sys, importlib
MODULE_DIR = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/script"
if MODULE_DIR not in sys.path:
    sys.path.insert(0, MODULE_DIR)

import regional_plot_tools
importlib.reload(regional_plot_tools)
# Out:
# <module 'regional_plot_tools' from '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/script/regional_plot_tools.py'>

# %%
import fine_map_susie_tools
import importlib
importlib.reload(fine_map_susie_tools)

from fine_map_susie_tools import build_lead_and_locus_tables

summary_json = build_lead_and_locus_tables(
    plink_stats_file="/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic",
    range_bp=1_000_000,
    windowsizekb=500,
    sig_level=5e-8,
    output_prefix="cteph_agp3k.lowfreq_common",
    enable_harmonize=False,
)
# Out:
# INFO:susie_prep:启动流程：SuSiE 精细定位前置（lead与locus生成）
# INFO:susie_prep:输入文件：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# INFO:susie_prep:参数：range_bp=1000000；windowsizekb=500；sig_level=5e-08
# INFO:susie_prep:参考序列（用于harmonize）：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/nagasaki_pipeline/data/hs38DH.fa
# INFO:susie_prep:是否启用harmonize：False
# INFO:susie_prep:已创建 gwaslab.Sumstats 对象，开始 basic_check()
# INFO:susie_prep:basic_check() 完成
# INFO:susie_prep:开始识别 lead 变体
# INFO:susie_prep:识别到 2 个 lead 变体
# INFO:susie_prep:lead 变体已写出：cteph_agp3k.lowfreq_common.lead_variants.tsv
# INFO:susie_prep:构建 locus：chr16:53887925:T:C；区间：16:53387925-54387925
# INFO:susie_prep:跳过 locus chr16:53887925:T:C 的 harmonize 处理 (enable_harmonize=False, ref_seq_path=/LARGE0/gr10478/b37974/Pulmonary_Hypertension/nagasaki_pipeline/data/hs38DH.fa)
# INFO:susie_prep:完成处理 locus：chr16:53887925:T:C（记录数：1933)
# INFO:susie_prep:构建 locus：chr17:13528059:G:A；区间：17:13028059-14028059
# INFO:susie_prep:跳过 locus chr17:13528059:G:A 的 harmonize 处理 (enable_harmonize=False, ref_seq_path=/LARGE0/gr10478/b37974/Pulmonary_Hypertension/nagasaki_pipeline/data/hs38DH.fa)
# INFO:susie_prep:完成处理 locus：chr17:13528059:G:A（记录数：2824)
# INFO:susie_prep:locus_summaries 已写出（pickle）：cteph_agp3k.lowfreq_common.locus_summaries.pkl
# INFO:susie_prep:JSON 摘要已写出：cteph_agp3k.lowfreq_common.summary.json
# INFO:susie_prep:流程结束，总耗时：40.55 秒

# %%
from fine_map_susie_tools import build_ld_matrices_from_summary

ld_json = build_ld_matrices_from_summary(
    summary_json_path=summary_json,
    bed_prefix='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common', 
    output_prefix="cteph_agp3k.lowfreq_common",
    sample_mode="ctrl", # "all", "case", "ctrl"
    case_prefix="PHOM"
)
# Out:
# [build_ld_matrices_from_summary] 样本选择：mode=ctrl，case_prefix=PHOM，纳入 2644/3016 个样本
# [build_ld_matrices_from_summary] 输出目录策略：汇总 JSON -> /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1；明细与PLINK产物 -> /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp
# [build_ld_matrices_from_summary] 运行：/home/b/b37974/plink --bfile /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common --keep-allele-order --r square --extract /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.extract.txt --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.r --keep /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/samples.keep.ctrl.txt
# [build_ld_matrices_from_summary] 运行：/home/b/b37974/plink --bfile /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common --keep-allele-order --r2 square --extract /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.extract.txt --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.r2 --keep /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/samples.keep.ctrl.txt
# [build_ld_matrices_from_summary] 运行：/home/b/b37974/plink --bfile /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common --keep-allele-order --r square --extract /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.extract.txt --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.r --keep /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/samples.keep.ctrl.txt
# [build_ld_matrices_from_summary] 运行：/home/b/b37974/plink --bfile /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common --keep-allele-order --r2 square --extract /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.extract.txt --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.r2 --keep /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/samples.keep.ctrl.txt
# [build_ld_matrices_from_summary] 完成：输出索引 JSON -> /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.json

# %%
# 重新加载模块以获取修复
import reginal_plot_tools_rev1
importlib.reload(reginal_plot_tools_rev1)

# 调用函数处理LD数据和统计信息
result_summary = reginal_plot_tools_rev1.process_ld_matrices_with_sum_stats(
    ld_json_file=ld_json,
    output_dir=None,  # 使用默认的self_ld目录
    n_jobs=4  # 并行进程数
)

print(f"处理完成，输出摘要文件: {result_summary}")
# Out:
# INFO:reginal_plot_tools_rev1:输出目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld
# INFO:reginal_plot_tools_rev1:读取LD JSON文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.json
# INFO:reginal_plot_tools_rev1:发现 2 个lead variants: ['chr16:53887925:T:C', 'chr17:13528059:G:A']
# INFO:reginal_plot_tools_rev1:开始并行处理，使用 4 个进程
# INFO:reginal_plot_tools_rev1:开始处理lead variant: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:开始处理lead variant: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:读取统计数据文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.sum_stat.tsv
# INFO:reginal_plot_tools_rev1:读取统计数据文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.sum_stat.tsv
# INFO:reginal_plot_tools_rev1:添加is_lead_variant列，lead variant: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:添加is_lead_variant列，lead variant: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:读取LD r值文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.ld_r.tsv
# INFO:reginal_plot_tools_rev1:读取LD r值文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.ld_r.tsv
# INFO:reginal_plot_tools_rev1:成功添加LD r值，匹配到 1933 个变体
# INFO:reginal_plot_tools_rev1:读取LD r2值文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.ld_r2.tsv
# INFO:reginal_plot_tools_rev1:成功添加LD r2值，匹配到 1933 个变体
# INFO:reginal_plot_tools_rev1:保存结果到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/chr16_53887925_T_C.ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:完成处理lead variant: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:✓ 成功处理: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:成功添加LD r值，匹配到 2824 个变体
# INFO:reginal_plot_tools_rev1:读取LD r2值文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.ld_r2.tsv
# INFO:reginal_plot_tools_rev1:成功添加LD r2值，匹配到 2824 个变体
# INFO:reginal_plot_tools_rev1:保存结果到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/chr17_13528059_G_A.ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:完成处理lead variant: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:✓ 成功处理: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:处理完成！
# INFO:reginal_plot_tools_rev1:- 总lead variants: 2
# INFO:reginal_plot_tools_rev1:- 成功处理: 2
# INFO:reginal_plot_tools_rev1:- 输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.ld_sum_stat_summary.json
# 处理完成，输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.ld_sum_stat_summary.json

# %%
# 重新加载模块以获取语法修复
import reginal_plot_tools_rev1
importlib.reload(reginal_plot_tools_rev1)

# 处理ToMMo LD数据
tommo_result_summary = reginal_plot_tools_rev1.process_ld_matrices_with_tommo(
    ld_json_file=ld_json, 
    tommo_dir='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/ToMMo_60KJPN/co-occurrence',  # 使用默认的ToMMo目录
    output_dir=None,  # 使用默认的tommo_ld目录
    n_jobs=4  # 并行进程数
)

print(f"ToMMo LD数据处理完成，输出摘要文件: {tommo_result_summary}")
# Out:
# INFO:reginal_plot_tools_rev1:输出目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld
# INFO:reginal_plot_tools_rev1:ToMMo数据目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/ToMMo_60KJPN/co-occurrence
# INFO:reginal_plot_tools_rev1:读取LD JSON文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.json
# INFO:reginal_plot_tools_rev1:发现 2 个lead variants: ['chr16:53887925:T:C', 'chr17:13528059:G:A']
# INFO:reginal_plot_tools_rev1:开始并行处理，使用 4 个进程
# INFO:reginal_plot_tools_rev1:开始处理lead variant (ToMMo): chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:开始处理lead variant (ToMMo): chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:读取统计数据文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.sum_stat.tsv
# INFO:reginal_plot_tools_rev1:读取统计数据文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.sum_stat.tsv
# INFO:reginal_plot_tools_rev1:添加is_lead_variant列，lead variant: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:添加is_lead_variant列，lead variant: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:查询ToMMo LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/ToMMo_60KJPN/co-occurrence/tommo-54kjpn-20230828-GRCh38-autosome-chr17-plink-r2.tsv.gz
# INFO:reginal_plot_tools_rev1:查询ToMMo LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/ToMMo_60KJPN/co-occurrence/tommo-54kjpn-20230828-GRCh38-autosome-chr16-plink-r2.tsv.gz
# INFO:reginal_plot_tools_rev1:成功查询到ToMMo数据，记录数: 96
# INFO:reginal_plot_tools_rev1:解析得到 96 条ToMMo记录
# INFO:reginal_plot_tools_rev1:ToMMo中关于lead variant的记录数: 96
# INFO:reginal_plot_tools_rev1:匹配并填充了 56 个变体的ToMMo r2值
# INFO:reginal_plot_tools_rev1:成功查询到ToMMo数据，记录数: 51
# INFO:reginal_plot_tools_rev1:解析得到 51 条ToMMo记录
# INFO:reginal_plot_tools_rev1:保存结果到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/chr16_53887925_T_C.tommo_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:完成处理lead variant (ToMMo): chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:✓ 成功处理(ToMMo): chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:ToMMo中关于lead variant的记录数: 51
# INFO:reginal_plot_tools_rev1:匹配并填充了 25 个变体的ToMMo r2值
# INFO:reginal_plot_tools_rev1:保存结果到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/chr17_13528059_G_A.tommo_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:完成处理lead variant (ToMMo): chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:✓ 成功处理(ToMMo): chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:ToMMo LD处理完成！
# INFO:reginal_plot_tools_rev1:- 总lead variants: 2
# INFO:reginal_plot_tools_rev1:- 成功处理: 2
# INFO:reginal_plot_tools_rev1:- ToMMo中总记录数: 147
# INFO:reginal_plot_tools_rev1:- 输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.tommo_ld_sum_stat_summary.json
# ToMMo LD数据处理完成，输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.tommo_ld_sum_stat_summary.json

# %%
# 计算资源不足警告⚠️

# 重新加载模块以获取语法修复
import reginal_plot_tools_rev1
importlib.reload(reginal_plot_tools_rev1)

eas_result_summary = reginal_plot_tools_rev1.process_ld_matrices_with_eas(
    ld_json_file=ld_json,
    eas_bed_prefix='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_all',  # 默认路径
    intersection_json='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/variant_intersection_summary.json',  # 默认：eas_ld_tmp/variant_intersection_summary.json
    output_dir=None,  # 默认：eas_ld/
    n_jobs=4
)

print(f"EAS LD数据处理完成，输出摘要文件: {eas_result_summary}")
# Out:
# INFO:reginal_plot_tools_rev1:输出目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld
# INFO:reginal_plot_tools_rev1:EAS bed前缀: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_all
# INFO:reginal_plot_tools_rev1:交集摘要JSON: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/variant_intersection_summary.json
# INFO:reginal_plot_tools_rev1:读取交集摘要JSON文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/variant_intersection_summary.json
# INFO:reginal_plot_tools_rev1:读取LD JSON文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.json
# INFO:reginal_plot_tools_rev1:发现 2 个lead variants: ['chr16:53887925:T:C', 'chr17:13528059:G:A']
# INFO:reginal_plot_tools_rev1:开始顺序处理lead variants
# INFO:reginal_plot_tools_rev1:处理 chr16:53887925:T:C...
# INFO:reginal_plot_tools_rev1:开始处理lead variant (EAS): chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:读取统计数据文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr16:53887925:T:C.sum_stat.tsv
# INFO:reginal_plot_tools_rev1:添加is_lead_variant列，lead variant: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:读取交集文件: eas_ld_tmp/chr16_53887925_T_C.intersect_variants.txt
# INFO:reginal_plot_tools_rev1:交集文件中有 1896 个共同变体
# INFO:reginal_plot_tools_rev1:交集文件中有 1896 个共同变体
# INFO:reginal_plot_tools_rev1:临时目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr16_53887925_T_C
# INFO:reginal_plot_tools_rev1:从lead variant提取染色体号: 16
# INFO:reginal_plot_tools_rev1:使用plink2提取变体子集...
# INFO:reginal_plot_tools_rev1:执行命令: /home/b/b37974/plink2 --bfile /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_all --chr 16 --extract eas_ld_tmp/chr16_53887925_T_C.intersect_variants.txt --make-bed --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr16_53887925_T_C/eas_subset --threads 4 --memory 16000
# INFO:reginal_plot_tools_rev1:使用plink1.9计算LD矩阵...
# INFO:reginal_plot_tools_rev1:LD矩阵文件已保存: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr16_53887925_T_C/ld_matrix.ld
# INFO:reginal_plot_tools_rev1:从bim文件读取到 1896 个变体ID
# INFO:reginal_plot_tools_rev1:LD矩阵维度: (1896, 1896)
# INFO:reginal_plot_tools_rev1:为LD矩阵添加了行名和列名
# INFO:reginal_plot_tools_rev1:带标签的LD矩阵已保存: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr16_53887925_T_C/ld_matrix_labeled.tsv
# INFO:reginal_plot_tools_rev1:成功匹配 1896 个变体的EAS LD值
# INFO:reginal_plot_tools_rev1:临时文件保留在: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr16_53887925_T_C
# INFO:reginal_plot_tools_rev1:保存结果到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/chr16_53887925_T_C.eas_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:完成处理lead variant (EAS): chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:✓ 成功处理(EAS): chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:处理 chr17:13528059:G:A...
# INFO:reginal_plot_tools_rev1:开始处理lead variant (EAS): chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:读取统计数据文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tmp/chr17:13528059:G:A.sum_stat.tsv
# INFO:reginal_plot_tools_rev1:添加is_lead_variant列，lead variant: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:读取交集文件: eas_ld_tmp/chr17_13528059_G_A.intersect_variants.txt
# INFO:reginal_plot_tools_rev1:交集文件中有 2781 个共同变体
# INFO:reginal_plot_tools_rev1:交集文件中有 2781 个共同变体
# INFO:reginal_plot_tools_rev1:临时目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr17_13528059_G_A
# INFO:reginal_plot_tools_rev1:从lead variant提取染色体号: 17
# INFO:reginal_plot_tools_rev1:使用plink2提取变体子集...
# INFO:reginal_plot_tools_rev1:执行命令: /home/b/b37974/plink2 --bfile /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_all --chr 17 --extract eas_ld_tmp/chr17_13528059_G_A.intersect_variants.txt --make-bed --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr17_13528059_G_A/eas_subset --threads 4 --memory 16000
# INFO:reginal_plot_tools_rev1:使用plink1.9计算LD矩阵...
# INFO:reginal_plot_tools_rev1:LD矩阵文件已保存: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr17_13528059_G_A/ld_matrix.ld
# INFO:reginal_plot_tools_rev1:从bim文件读取到 2781 个变体ID
# INFO:reginal_plot_tools_rev1:LD矩阵维度: (2781, 2781)
# INFO:reginal_plot_tools_rev1:为LD矩阵添加了行名和列名
# INFO:reginal_plot_tools_rev1:带标签的LD矩阵已保存: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr17_13528059_G_A/ld_matrix_labeled.tsv
# INFO:reginal_plot_tools_rev1:成功匹配 2781 个变体的EAS LD值
# INFO:reginal_plot_tools_rev1:临时文件保留在: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld_tmp/chr17_13528059_G_A
# INFO:reginal_plot_tools_rev1:保存结果到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/chr17_13528059_G_A.eas_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:完成处理lead variant (EAS): chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:✓ 成功处理(EAS): chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:EAS LD处理完成！
# INFO:reginal_plot_tools_rev1:- 总lead variants: 2
# INFO:reginal_plot_tools_rev1:- 成功处理: 2
# INFO:reginal_plot_tools_rev1:- 总匹配变体数: 4677
# INFO:reginal_plot_tools_rev1:- 输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.eas_ld_sum_stat_summary.json
# EAS LD数据处理完成，输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.eas_ld_sum_stat_summary.json

# %%
# 重新加载模块以获取语法修复
import reginal_plot_tools_rev1
importlib.reload(reginal_plot_tools_rev1)

merged_summary = reginal_plot_tools_rev1.merge_ld_data_sources(
    self_ld_summary=result_summary,
    tommo_ld_summary=tommo_result_summary,
    eas_ld_summary='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.eas_ld_sum_stat_summary.json',
    output_dir=None  # 使用默认的ld_summary目录
)
# Out:
# INFO:reginal_plot_tools_rev1:输出目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/ld_summary
# INFO:reginal_plot_tools_rev1:读取LD摘要JSON文件...
# INFO:reginal_plot_tools_rev1:✓ 读取自己的LD数据摘要: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.ld_sum_stat_summary.json
# INFO:reginal_plot_tools_rev1:✓ 读取ToMMo LD数据摘要: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.tommo_ld_sum_stat_summary.json
# INFO:reginal_plot_tools_rev1:✓ 读取EAS LD数据摘要: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/cteph_agp3k.lowfreq_common.ld_matrices_by_lead.summary.eas_ld_sum_stat_summary.json
# INFO:reginal_plot_tools_rev1:发现 2 个lead variants
# INFO:reginal_plot_tools_rev1:处理lead variant: chr16:53887925:T:C
# INFO:reginal_plot_tools_rev1:  读取自己的LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/chr16_53887925_T_C.ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:  基础数据: 1933 个变体
# INFO:reginal_plot_tools_rev1:  读取ToMMo LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/chr16_53887925_T_C.tommo_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:  ✓ 添加ToMMo LD数据
# INFO:reginal_plot_tools_rev1:  读取EAS LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/chr16_53887925_T_C.eas_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:  ✓ 添加EAS LD数据
# INFO:reginal_plot_tools_rev1:  保存合并数据到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/ld_summary/chr16_53887925_T_C.merged_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:✓ 成功合并lead variant chr16:53887925:T:C 的LD数据
# INFO:reginal_plot_tools_rev1:处理lead variant: chr17:13528059:G:A
# INFO:reginal_plot_tools_rev1:  读取自己的LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/self_ld/chr17_13528059_G_A.ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:  基础数据: 2824 个变体
# INFO:reginal_plot_tools_rev1:  读取ToMMo LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/tommo_ld/chr17_13528059_G_A.tommo_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:  ✓ 添加ToMMo LD数据
# INFO:reginal_plot_tools_rev1:  读取EAS LD数据: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/eas_ld/chr17_13528059_G_A.eas_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:  ✓ 添加EAS LD数据
# INFO:reginal_plot_tools_rev1:  保存合并数据到: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/ld_summary/chr17_13528059_G_A.merged_ld_sum_stat.tsv
# INFO:reginal_plot_tools_rev1:✓ 成功合并lead variant chr17:13528059:G:A 的LD数据
# INFO:reginal_plot_tools_rev1:
# 合并LD数据完成！
# INFO:reginal_plot_tools_rev1:- 总lead variants: 2
# INFO:reginal_plot_tools_rev1:- 成功合并: 2
# INFO:reginal_plot_tools_rev1:- 输出摘要文件: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/06.regional_plot_rev1/ld_summary/merged_ld_sum_stat_summary.json
# INFO:reginal_plot_tools_rev1:
# 总体统计:
# INFO:reginal_plot_tools_rev1:- 包含自己LD r²数据的变体总数: 4757
# INFO:reginal_plot_tools_rev1:- 包含ToMMo r²数据的变体总数: 81
# INFO:reginal_plot_tools_rev1:- 包含EAS r²数据的变体总数: 4677
