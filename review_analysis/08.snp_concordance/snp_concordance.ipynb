# %%
import sys, importlib
MODULE_DIR = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/script"
if MODULE_DIR not in sys.path:
    sys.path.insert(0, MODULE_DIR)

import snp_concordance_tools
importlib.reload(snp_concordance_tools)
# Out:
# <module 'snp_concordance_tools' from '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/script/snp_concordance_tools.py'>

# %%
from snp_concordance_tools import compare_genotypes

result_dict = compare_genotypes(
    prefix1 = '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/19.tommo_panel_filter/cteph_agp3k.lowfreq_common',
    prefix2 = '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/03.extract_common/cteph_agp3k.array.common',
    snp_id = 'chr9:65411978:C:T',
    missing_mode = 'exclude_any',
)
# Out:
# 2025-11-13 23:09:06 - INFO - ================================================================================
# 2025-11-13 23:09:06 - INFO - 开始基因型一致性分析
# 2025-11-13 23:09:06 - INFO - 文件1: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/19.tommo_panel_filter/cteph_agp3k.lowfreq_common
# 2025-11-13 23:09:06 - INFO - 文件2: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/03.extract_common/cteph_agp3k.array.common
# 2025-11-13 23:09:06 - INFO - SNP ID: chr9:65411978:C:T
# 2025-11-13 23:09:06 - INFO - 缺失值处理模式: exclude_any
# 2025-11-13 23:09:06 - INFO - ================================================================================
# 2025-11-13 23:09:06 - INFO - 输出目录: tmp
# 2025-11-13 23:09:06 - INFO - 输出文件前缀: chr9_65411978_C_T
# 2025-11-13 23:09:06 - INFO - 检查输入文件...
# 2025-11-13 23:09:06 - INFO - 输入文件检查通过
# 2025-11-13 23:09:06 - INFO - 创建临时工作目录: /tmp/tmpmk6_j2u7
# 2025-11-13 23:09:06 - INFO - 提取文件1中的SNP基因型数据...
# ...

# %%
result_dict
# Out:
# {'snp_id': 'chr9:65411978:C:T',
#  'file1_prefix': '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/19.tommo_panel_filter/cteph_agp3k.lowfreq_common',
#  'file2_prefix': '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/03.extract_common/cteph_agp3k.array.common',
#  'n_common_samples': 1689,
#  'missing_mode': 'exclude_any',
#  'confusion_matrix': {'file1_GT_0': {'file2_GT_0': 118,
#    'file2_GT_1': 9,
#    'file2_GT_2': 11,
#    'file2_GT_missing': 0},
#   'file1_GT_1': {'file2_GT_0': 8,
#    'file2_GT_1': 632,
#    'file2_GT_2': 74,
#    'file2_GT_missing': 0},
#   'file1_GT_2': {'file2_GT_0': 3,
#    'file2_GT_1': 31,
#    'file2_GT_2': 761,
#    'file2_GT_missing': 0},
#   'file1_GT_missing': {'file2_GT_0': 2,
#    'file2_GT_1': 20,
#    'file2_GT_2': 20,
#    'file2_GT_missing': 0}},
#  'file1_stats': {'aaf': 0.6994535519125683, 'miss_rate': 0.02486678507992895},
# ...
