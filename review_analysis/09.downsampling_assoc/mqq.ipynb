# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

array_add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/09.downsampling_assoc/cteph_agp3k.downsampled.sex.10pc.additive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(array_add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/11/13 23:35:36 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/11/13 23:35:36 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/11/13 23:35:36 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/11/13 23:35:36 Start to load format from formatbook....
# 2025/11/13 23:35:36  -plink2 format meta info:
# 2025/11/13 23:35:36   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/11/13 23:35:36   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/11/13 23:35:36   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/11/13 23:35:36   - last_check_date  :  20220806
# 2025/11/13 23:35:36  -plink2 to gwaslab format dictionary:
# 2025/11/13 23:35:36   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/11/13 23:35:36   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/11/13 23:35:36 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/review_analysis/09.downsampling_assoc/cteph_agp3k.downsampled.sex.10pc.additive.PHENO1.glm.logistic
# 2025/11/13 23:35:44  -Reading columns          : ALT,A1,ID,#CHROM,POS,P,OMITTED,L95,OR,U95,A1_FREQ,Z_STAT,REF,LOG(OR)_SE,OBS_CT
# 2025/11/13 23:35:44  -Renaming columns to      : ALT,EA,SNPID,CHR,POS,P,NEA,OR_95L,OR,OR_95U,EAF,Z,REF,SE,N
# 2025/11/13 23:35:44  -Current Dataframe shape : 4940905  x  15
# 2025/11/13 23:35:44  -Initiating a status column: STATUS ...
# 2025/11/13 23:35:44  -Genomic coordinates are based on GRCh38/hg38...
# 2025/11/13 23:35:44  -EA,REF and ALT columns are available: assigning NEA...
# 2025/11/13 23:35:45  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/11/13 23:35:45  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/11/13 23:35:46 Start to reorder the columns...v3.6.0
# 2025/11/13 23:35:46  -Current Dataframe shape : 4940905 x 16 ; Memory usage: 474.58 MB
# 2025/11/13 23:35:46  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/11/13 23:35:47 Finished reordering the columns.
# 2025/11/13 23:35:47  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/11/13 23:35:47  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/11/13 23:35:47  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/11/13 23:35:47  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/11/13 23:35:47  -Current Dataframe memory usage: 479.29 MB
# 2025/11/13 23:35:47 Finished loading data successfully!
# 2025/11/13 23:35:47 Path component detected: ['139731807919120']
# 2025/11/13 23:35:47 Creating path: ./139731807919120

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/11/13 23:35:50 Start to create MQQ plot...v3.6.0:
# 2025/11/13 23:35:50  -Genomic coordinates version: 38...
# 2025/11/13 23:35:50  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/11/13 23:35:50  -Raw input contains 4940905 variants...
# 2025/11/13 23:35:50  -MQQ plot layout mode is : mqq
# 2025/11/13 23:35:51 Finished loading specified columns from the sumstats.
# 2025/11/13 23:35:51 Start data conversion and sanity check:
# 2025/11/13 23:35:51  -Removed 0 variants with nan in CHR or POS column ...
# 2025/11/13 23:35:51  -Removed 0 variants with CHR <=0...
# 2025/11/13 23:35:52  -Removed 729 variants with nan in P column ...
# 2025/11/13 23:35:52  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/11/13 23:35:52  -Sumstats P values are being converted to -log10(P)...
# 2025/11/13 23:35:52  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/11/13 23:35:53  -Converting data above cut line...
# 2025/11/13 23:35:53  -Maximum -log10(P) value is 6.083496044661585 .
# 2025/11/13 23:35:53 Finished data conversion and sanity check.
# 2025/11/13 23:35:53 Start to create MQQ plot with 4940176 variants...
# 2025/11/13 23:35:58  -Creating background plot...
# 2025/11/13 23:36:10 Finished creating MQQ plot successfully!
# 2025/11/13 23:36:10 Start to extract variants for annotation...
# 2025/11/13 23:36:10 Finished extracting variants for annotation...
# 2025/11/13 23:36:10 Start to process figure arts.
# 2025/11/13 23:36:10  -Processing X ticks...
# 2025/11/13 23:36:10  -Processing X labels...
# 2025/11/13 23:36:10  -Processing Y labels...
# 2025/11/13 23:36:10  -Processing Y tick lables...
# 2025/11/13 23:36:10  -Processing Y labels...
# 2025/11/13 23:36:10  -Processing lines...
# 2025/11/13 23:36:10 Finished processing figure arts.
# 2025/11/13 23:36:10 Start to annotate variants...
# 2025/11/13 23:36:10  -Skip annotating
# 2025/11/13 23:36:10 Finished annotating variants.
# 2025/11/13 23:36:10 Start to create QQ plot with 4940176 variants:
# 2025/11/13 23:36:10  -Plotting all variants...
# 2025/11/13 23:36:11  -Expected range of P: (0,1.0)
# 2025/11/13 23:36:11  -Lambda GC (MLOG10P mode) at 0.5 is   1.09623
# 2025/11/13 23:36:11  -Processing Y tick lables...
# 2025/11/13 23:36:11 Finished creating QQ plot successfully!
# 2025/11/13 23:36:11 Start to save figure...
# 2025/11/13 23:36:11  -Skip saving figure!
# 2025/11/13 23:36:11 Finished saving figure...
# 2025/11/13 23:36:12 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f15182a0490>)
