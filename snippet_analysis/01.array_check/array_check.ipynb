# %%
import sys, importlib
MODULE_DIR = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/scripts"
if MODULE_DIR not in sys.path:
    sys.path.insert(0, MODULE_DIR)

import array_check_prepare_tools
importlib.reload(array_check_prepare_tools)
# Out:
# <module 'array_check_prepare_tools' from '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/scripts/array_check_prepare_tools.py'>

# %%
array_vcf_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/array/07.z3.re.select.ids.vcf/cteph_agp3k.ajsa.qc.rechr.norm.reselect.ids.vcf.gz"

# %%
from array_check_prepare_tools import vcf_to_plink_with_optional_keep

array_plink_result = vcf_to_plink_with_optional_keep(
    vcf_gz=array_vcf_path,
    out_prefix="cteph_agp3k_array",
    enable_keep=True,
    keep_fam_path="/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common.fam",
    enable_extract=True,
    extract_bim_path="/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/18.tommo_panel_filter/cteph_agp3k.lowfreq_common.bim",
    sum_stat="/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic",
    threads=16
)
# Out:
# [array_check_prepare_tools] 开始任务：VCF 转换为 PLINK 二进制格式（--double-id）
# [array_check_prepare_tools] 未指定 out_dir，默认输出到 tmp/ 目录：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/01.array_check/tmp
# [array_check_prepare_tools] 输出目录已准备：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/01.array_check/tmp
# [array_check_prepare_tools] 步骤 1/2：执行 plink2 VCF 导入与 --make-bed（确保 FID=IID）
# [array_check_prepare_tools] 命令：/home/b/b37974/plink2 --vcf /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/array/07.z3.re.select.ids.vcf/cteph_agp3k.ajsa.qc.rechr.norm.reselect.ids.vcf.gz --double-id --make-bed --out /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/01.array_check/tmp/cteph_agp3k_array --threads 16
# [array_check_prepare_tools] 命令执行成功。
# [array_check_prepare_tools] .fam 文件就绪：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/01.array_check/tmp/cteph_agp3k_array.fam
# ...

# %%
from array_check_prepare_tools import run_plink2_gwas_association

array_assoc_result = run_plink2_gwas_association(
    bed_prefix='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/array/09.maf_hwe_qc/cteph_agp3k.ajsa.mind.geno.rm_mav.auto_chr.maf_hwe_qc',
    pheno_file="/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/19.cov_pheno_prepare/cteph_agp3k.bbj.projection.pheno_df.csv",
    pheno_name="PHENO1",
    covar_file="/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/19.cov_pheno_prepare/cteph_agp3k.bbj.projection.cov_df.no_age.csv",
    covar_name="SEX, PC1_AVG-PC10_AVG",
    model="additive",
    out_prefix="cteph_agp3k.array.sex.10pc.additive",
    threads=16
)
# Out:
# [array_check_prepare_tools] 开始任务：使用 plink2 进行 GWAS 关联分析
# [array_check_prepare_tools] 未指定 out_dir，默认输出到 tmp/ 目录：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/01.array_check/tmp
# [array_check_prepare_tools] 原始协变量名称：SEX, PC1_AVG-PC10_AVG
# [array_check_prepare_tools] 清理后协变量名称：SEX,PC1_AVG-PC10_AVG
# [array_check_prepare_tools] 执行 GWAS 关联分析
# ...
