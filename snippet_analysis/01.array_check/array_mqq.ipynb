# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

array_add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/01.array_check/tmp/cteph_agp3k.array.sex.10pc.additive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(array_add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/12/03 00:01:44 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/12/03 00:01:44 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/12/03 00:01:44 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/12/03 00:01:44 Start to load format from formatbook....
# 2025/12/03 00:01:44  -plink2 format meta info:
# 2025/12/03 00:01:44   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/12/03 00:01:44   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/12/03 00:01:44   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/12/03 00:01:44   - last_check_date  :  20220806
# 2025/12/03 00:01:44  -plink2 to gwaslab format dictionary:
# 2025/12/03 00:01:44   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/12/03 00:01:44   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# ...

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/12/03 00:01:48 Start to create MQQ plot...v3.6.0:
# 2025/12/03 00:01:48  -Genomic coordinates version: 38...
# 2025/12/03 00:01:48  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/12/03 00:01:48  -Raw input contains 290383 variants...
# 2025/12/03 00:01:48  -MQQ plot layout mode is : mqq
# 2025/12/03 00:01:48 Finished loading specified columns from the sumstats.
# 2025/12/03 00:01:48 Start data conversion and sanity check:
# 2025/12/03 00:01:48  -Removed 0 variants with nan in CHR or POS column ...
# 2025/12/03 00:01:48  -Removed 0 variants with CHR <=0...
# 2025/12/03 00:01:48  -Removed 68 variants with nan in P column ...
# 2025/12/03 00:01:48  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/12/03 00:01:48  -Sumstats P values are being converted to -log10(P)...
# 2025/12/03 00:01:48  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/12/03 00:01:48  -Converting data above cut line...
# ...

# %%
sumstats_add.data[sumstats_add.data["SNPID"] == "chr16:53882967:G:A"]
# Out:
#                      SNPID  CHR       POS EA NEA       EAF        SE        Z  \
# 244692  chr16:53882967:G:A   16  53882967  A   G  0.219657  0.109653  3.85378
#
#                P       OR  OR_95L   OR_95U     N   STATUS REF ALT
# 244692  0.000116  1.52589  1.2308  1.89173  1689  3899999   G   A
