# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

array_add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/04.array_assoc_result/cteph_agp3k.array.sex.10pc.additive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(array_add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/10/30 11:53:21 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/10/30 11:53:21 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/10/30 11:53:21 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/10/30 11:53:21 Start to load format from formatbook....
# 2025/10/30 11:53:21  -plink2 format meta info:
# 2025/10/30 11:53:21   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/10/30 11:53:21   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/10/30 11:53:21   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/10/30 11:53:21   - last_check_date  :  20220806
# 2025/10/30 11:53:21  -plink2 to gwaslab format dictionary:
# 2025/10/30 11:53:21   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/10/30 11:53:21   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# ...

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/10/29 22:54:19 Start to create MQQ plot...v3.6.0:
# 2025/10/29 22:54:19  -Genomic coordinates version: 38...
# 2025/10/29 22:54:19  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/10/29 22:54:19  -Raw input contains 4940905 variants...
# 2025/10/29 22:54:19  -MQQ plot layout mode is : mqq
# 2025/10/29 22:54:19 Finished loading specified columns from the sumstats.
# 2025/10/29 22:54:19 Start data conversion and sanity check:
# 2025/10/29 22:54:20  -Removed 0 variants with nan in CHR or POS column ...
# 2025/10/29 22:54:20  -Removed 0 variants with CHR <=0...
# 2025/10/29 22:54:20  -Removed 757 variants with nan in P column ...
# 2025/10/29 22:54:21  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/10/29 22:54:21  -Sumstats P values are being converted to -log10(P)...
# 2025/10/29 22:54:21  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/10/29 22:54:22  -Converting data above cut line...
# ...

# %%
sumstats_add.data[sumstats_add.data['SNPID'] == 'chr16:13528180:G:A']
# Out:
# Empty DataFrame
# Columns: [SNPID, CHR, POS, EA, NEA, EAF, SE, Z, P, OR, OR_95L, OR_95U, N, STATUS, REF, ALT]
# Index: []

# %%
sumstats_add.get_lead()
# Out:
# 2025/10/30 12:07:00 Start to extract lead variants...v3.6.0
# 2025/10/30 12:07:00  -Current Dataframe shape : 4940905 x 16 ; Memory usage: 479.29 MB
# 2025/10/30 12:07:00  -Processing 4940905 variants...
# 2025/10/30 12:07:00  -Significance threshold : 5e-08
# 2025/10/30 12:07:00  -Sliding window size: 500  kb
# 2025/10/30 12:07:01  -Using P for extracting lead variants...
# 2025/10/30 12:07:01  -Found 3 significant variants in total...
# 2025/10/30 12:07:01  -Identified 3 lead variants!
# 2025/10/30 12:07:01 Finished extracting lead variants.
#                       SNPID  CHR        POS EA NEA       EAF        SE  \
# 203396   chr1:147027142:G:C    1  147027142  C   G  0.636767  0.112221
# 2841954   chr9:60545749:A:G    9   60545749  G   A  0.715512  0.120489
# 2842032   chr9:65411978:C:T    9   65411978  T   C  0.717584  0.121828
#
#                Z             P       OR   OR_95L   OR_95U     N   STATUS REF  \
# ...
