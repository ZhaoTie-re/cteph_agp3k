# %%
import pandas as pd
import numpy as np
import gwaslab as gl
import logging
import matplotlib.pyplot as plt

# 设置全局日志级别变量
logging.getLogger("matplotlib").setLevel(logging.ERROR)
plt.style.use('default')

sig_level = 5e-8

array_add_path = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/04.array_assoc_result/cteph_agp3k.array.sex.10pc.additive.PHENO1.glm.logistic"

# %%
sumstats_add = gl.Sumstats(array_add_path, fmt="plink2", build='38', ea='A1', nea='OMITTED', OR_95L='L95', OR_95U='U95')
# Out:
# 2025/12/03 00:19:24 GWASLab v3.6.0 https://cloufield.github.io/gwaslab/
# 2025/12/03 00:19:24 (C) 2022-2025, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2025/12/03 00:19:24 Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:51:40)
# [GCC 13.3.0]
# 2025/12/03 00:19:24 Start to load format from formatbook....
# 2025/12/03 00:19:24  -plink2 format meta info:
# 2025/12/03 00:19:24   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2025/12/03 00:19:24   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2025/12/03 00:19:24   - format_version  : Alpha 3.3 final (3 Jun)
# 2025/12/03 00:19:24   - last_check_date  :  20220806
# 2025/12/03 00:19:24  -plink2 to gwaslab format dictionary:
# 2025/12/03 00:19:24   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2025/12/03 00:19:24   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2025/12/03 00:19:24 Start to initialize gl.Sumstats from file :/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/04.array_assoc_result/cteph_agp3k.array.sex.10pc.additive.PHENO1.glm.logistic
# 2025/12/03 00:19:29  -Reading columns          : REF,LOG(OR)_SE,ID,L95,OMITTED,OBS_CT,OR,Z_STAT,#CHROM,P,U95,ALT,POS,A1,A1_FREQ
# 2025/12/03 00:19:29  -Renaming columns to      : REF,SE,SNPID,OR_95L,NEA,N,OR,Z,CHR,P,OR_95U,ALT,POS,EA,EAF
# 2025/12/03 00:19:29  -Current Dataframe shape : 4535673  x  15
# 2025/12/03 00:19:29  -Initiating a status column: STATUS ...
# 2025/12/03 00:19:29  -Genomic coordinates are based on GRCh38/hg38...
# 2025/12/03 00:19:30  -EA,REF and ALT columns are available: assigning NEA...
# 2025/12/03 00:19:30  -For variants with EA == ALT : assigning REF to NEA ...
# 2025/12/03 00:19:31  -For variants with EA != ALT : assigning ALT to NEA ...
# 2025/12/03 00:19:31 Start to reorder the columns...v3.6.0
# 2025/12/03 00:19:31  -Current Dataframe shape : 4535673 x 16 ; Memory usage: 437.48 MB
# 2025/12/03 00:19:31  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,EAF,SE,Z,P,OR,OR_95L,OR_95U,N,STATUS,REF,ALT
# 2025/12/03 00:19:32 Finished reordering the columns.
# 2025/12/03 00:19:32  -Trying to convert datatype for CHR: string -> Int64...Int64
# 2025/12/03 00:19:32  -Column  : SNPID  CHR   POS   EA       NEA      EAF     SE      Z       P       OR      OR_95L  OR_95U  N     STATUS   REF      ALT
# 2025/12/03 00:19:32  -DType   : object Int64 int64 category category float64 float64 float64 float64 float64 float64 float64 int64 category category category
# 2025/12/03 00:19:32  -Verified: T      T     T     T        T        T       T       T       T       T       T       T       T     T        T        T
# 2025/12/03 00:19:32  -Current Dataframe memory usage: 441.81 MB
# 2025/12/03 00:19:32 Finished loading data successfully!
# 2025/12/03 00:19:32 Path component detected: ['140088471390432']
# 2025/12/03 00:19:32 Creating path: ./140088471390432

# %%
sumstats_add.plot_mqq()
# Out:
# 2025/12/03 00:19:35 Start to create MQQ plot...v3.6.0:
# 2025/12/03 00:19:35  -Genomic coordinates version: 38...
# 2025/12/03 00:19:35  -Genome-wide significance level to plot is set to 5e-08 ...
# 2025/12/03 00:19:35  -Raw input contains 4535673 variants...
# 2025/12/03 00:19:35  -MQQ plot layout mode is : mqq
# 2025/12/03 00:19:35 Finished loading specified columns from the sumstats.
# 2025/12/03 00:19:35 Start data conversion and sanity check:
# 2025/12/03 00:19:36  -Removed 0 variants with nan in CHR or POS column ...
# 2025/12/03 00:19:36  -Removed 0 variants with CHR <=0...
# 2025/12/03 00:19:36  -Removed 635 variants with nan in P column ...
# 2025/12/03 00:19:36  -Sanity check after conversion: 0 variants with P value outside of (0,1] will be removed...
# 2025/12/03 00:19:37  -Sumstats P values are being converted to -log10(P)...
# 2025/12/03 00:19:37  -Sanity check: 0 na/inf/-inf variants will be removed...
# 2025/12/03 00:19:37  -Converting data above cut line...
# 2025/12/03 00:19:37  -Maximum -log10(P) value is 8.20118367761405 .
# 2025/12/03 00:19:37 Finished data conversion and sanity check.
# 2025/12/03 00:19:37 Start to create MQQ plot with 4535038 variants...
# 2025/12/03 00:19:41  -Creating background plot...
# 2025/12/03 00:19:51 Finished creating MQQ plot successfully!
# 2025/12/03 00:19:51 Start to extract variants for annotation...
# 2025/12/03 00:19:51  -Found 3 significant variants with a sliding window size of 500 kb...
# 2025/12/03 00:19:51 Finished extracting variants for annotation...
# 2025/12/03 00:19:51 Start to process figure arts.
# 2025/12/03 00:19:51  -Processing X ticks...
# 2025/12/03 00:19:51  -Processing X labels...
# 2025/12/03 00:19:51  -Processing Y labels...
# 2025/12/03 00:19:51  -Processing Y tick lables...
# 2025/12/03 00:19:51  -Processing Y labels...
# 2025/12/03 00:19:51  -Processing lines...
# 2025/12/03 00:19:51 Finished processing figure arts.
# 2025/12/03 00:19:51 Start to annotate variants...
# 2025/12/03 00:19:51  -Skip annotating
# 2025/12/03 00:19:51 Finished annotating variants.
# 2025/12/03 00:19:51 Start to create QQ plot with 4535038 variants:
# 2025/12/03 00:19:51  -Plotting all variants...
# 2025/12/03 00:19:52  -Expected range of P: (0,1.0)
# 2025/12/03 00:19:52  -Lambda GC (MLOG10P mode) at 0.5 is   1.11179
# 2025/12/03 00:19:52  -Processing Y tick lables...
# 2025/12/03 00:19:52 Finished creating QQ plot successfully!
# 2025/12/03 00:19:52 Start to save figure...
# 2025/12/03 00:19:52  -Skip saving figure!
# 2025/12/03 00:19:52 Finished saving figure...
# 2025/12/03 00:19:52 Finished creating plot successfully!
# (<Figure size 3000x1000 with 2 Axes>, <gwaslab.g_Log.Log at 0x7f6822eb3460>)

# %%
sumstats_add.data[sumstats_add.data['SNPID'] == 'chr17:13528059:G:A']
# Out:
#                       SNPID  CHR       POS EA NEA       EAF        SE  \
# 4377858  chr17:13528059:G:A   17  13528059  A   G  0.046477  0.200491
#
#                Z         P       OR   OR_95L   OR_95U     N   STATUS REF ALT
# 4377858  3.90927  0.000093  2.18972  1.47819  3.24375  1689  3899999   G   A

# %%
sumstats_add.get_lead()
# Out:
# 2025/11/13 18:40:47 Start to extract lead variants...v3.6.0
# 2025/11/13 18:40:47  -Current Dataframe shape : 4940905 x 16 ; Memory usage: 479.29 MB
# 2025/11/13 18:40:47  -Processing 4940905 variants...
# 2025/11/13 18:40:47  -Significance threshold : 5e-08
# 2025/11/13 18:40:47  -Sliding window size: 500  kb
# 2025/11/13 18:40:48  -Using P for extracting lead variants...
# 2025/11/13 18:40:48  -Found 3 significant variants in total...
# 2025/11/13 18:40:48  -Identified 3 lead variants!
# 2025/11/13 18:40:48 Finished extracting lead variants.
#                       SNPID  CHR        POS EA NEA       EAF        SE  \
# 203396   chr1:147027142:G:C    1  147027142  C   G  0.636767  0.112221
# 2841954   chr9:60545749:A:G    9   60545749  G   A  0.715512  0.120489
# 2842032   chr9:65411978:C:T    9   65411978  T   C  0.717584  0.121828
#
#                Z             P       OR   OR_95L   OR_95U     N   STATUS REF  \
# 203396   5.87491  4.230820e-09  1.93342  1.55168  2.40907  1689  3899999   G
# 2841954  5.46948  4.513470e-08  1.93288  1.52632  2.44774  1689  3899999   A
# 2842032  5.65865  1.525660e-08  1.99248  1.56926  2.52984  1689  3899999   C
#
#         ALT
# 203396    C
# 2841954   G
# 2842032   T
