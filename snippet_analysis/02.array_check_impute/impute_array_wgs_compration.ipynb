# %%
import sys, importlib
MODULE_DIR = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/scripts"
if MODULE_DIR not in sys.path:
    sys.path.insert(0, MODULE_DIR)

import array_check_prepare_tools
importlib.reload(array_check_prepare_tools)
# Out:
# <module 'array_check_prepare_tools' from '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/scripts/array_check_prepare_tools.py'>

# %%
array_sumstat = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/04.array_assoc_result/cteph_agp3k.array.sex.10pc.additive.PHENO1.glm.logistic"
wgs_sumstat = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic"

# %%
from array_check_prepare_tools import harmonize_and_convert_sumstat

array_sumstat_json = harmonize_and_convert_sumstat(
    plink_stats_file=array_sumstat,
    output_prefix='cteph_agp3k.array',
    enable_harmonize=False,
)
# Out:
# INFO:harmonize_sumstat:启动流程：汇总统计文件协调与 beta 转换
# INFO:harmonize_sumstat:输入文件：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/04.array_assoc_result/cteph_agp3k.array.sex.10pc.additive.PHENO1.glm.logistic
# INFO:harmonize_sumstat:参考序列（用于harmonize）：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/nagasaki_pipeline/data/hs38DH.fa
# INFO:harmonize_sumstat:是否启用等位基因协调：False
# INFO:harmonize_sumstat:已创建 gwaslab.Sumstats 对象，开始 basic_check()
# INFO:harmonize_sumstat:basic_check() 完成
# INFO:harmonize_sumstat:原始变体数：4940148
# INFO:harmonize_sumstat:开始 OR 到 beta 转换
# INFO:harmonize_sumstat:OR 到 beta 转换完成
# INFO:harmonize_sumstat:跳过等位基因方向协调（enable_harmonize=False）
# INFO:harmonize_sumstat:最终变体数：4940148
# INFO:harmonize_sumstat:协调后汇总统计已写出：cteph_agp3k.array.harmonized_sumstat.tsv
# INFO:harmonize_sumstat:JSON 摘要已写出：cteph_agp3k.array.summary.json
# INFO:harmonize_sumstat:流程结束，总耗时：75.99 秒
# [array_check_prepare_tools]
# === 汇总统计文件协调与转换完成 ===
# ...

# %%
from array_check_prepare_tools import harmonize_and_convert_sumstat

wgs_sumstat_json = harmonize_and_convert_sumstat(
    plink_stats_file=wgs_sumstat,
    output_prefix='cteph_agp3k.wgs',
    enable_harmonize=False,
)
# Out:
# INFO:harmonize_sumstat:启动流程：汇总统计文件协调与 beta 转换
# INFO:harmonize_sumstat:输入文件：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/analysis/assoc_plink2/results/01.assoc_result/additive/cteph_agp3k.sex.10pc.additive.PHENO1.glm.logistic
# INFO:harmonize_sumstat:参考序列（用于harmonize）：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/nagasaki_pipeline/data/hs38DH.fa
# INFO:harmonize_sumstat:是否启用等位基因协调：False
# INFO:harmonize_sumstat:已创建 gwaslab.Sumstats 对象，开始 basic_check()
# INFO:harmonize_sumstat:basic_check() 完成
# INFO:harmonize_sumstat:原始变体数：5314694
# INFO:harmonize_sumstat:开始 OR 到 beta 转换
# INFO:harmonize_sumstat:OR 到 beta 转换完成
# INFO:harmonize_sumstat:跳过等位基因方向协调（enable_harmonize=False）
# INFO:harmonize_sumstat:最终变体数：5314694
# INFO:harmonize_sumstat:协调后汇总统计已写出：cteph_agp3k.wgs.harmonized_sumstat.tsv
# INFO:harmonize_sumstat:JSON 摘要已写出：cteph_agp3k.wgs.summary.json
# INFO:harmonize_sumstat:流程结束，总耗时：85.53 秒
# [array_check_prepare_tools]
# === 汇总统计文件协调与转换完成 ===
# ...

# %%
from array_check_prepare_tools import merge_harmonized_sumstats

merge = merge_harmonized_sumstats(
    wgs_path=wgs_sumstat_json['harmonized_tsv'],
    array_path=array_sumstat_json['harmonized_tsv'],
    output_prefix="cteph_agp3k.array_wgs_compration",
)
# Out:
# [array_check_prepare_tools] 开始任务：合并两个 harmonized sumstat 文件
# [array_check_prepare_tools] 未指定 out_dir，默认输出到当前工作目录：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute
# [array_check_prepare_tools] 读取 WGS 文件：cteph_agp3k.wgs.harmonized_sumstat.tsv
# [array_check_prepare_tools] WGS 文件读取成功，行数：5314694
# [array_check_prepare_tools] 读取 Array 文件：cteph_agp3k.array.harmonized_sumstat.tsv
# [array_check_prepare_tools] Array 文件读取成功，行数：4940148
# [array_check_prepare_tools] WGS 提取字段后行数：5314694
# [array_check_prepare_tools] Array 提取字段后行数：4940148
# [array_check_prepare_tools] 重命名列完成
# [array_check_prepare_tools] WGS 列名: ['SNPID', 'EAF_wgs', 'BETA_wgs', 'SE_wgs', 'OR_wgs', 'OR_95L_wgs', 'OR_95U_wgs', 'P_wgs', 'N_wgs']
# [array_check_prepare_tools] Array 列名: ['SNPID', 'EAF_array', 'BETA_array', 'SE_array', 'OR_array', 'OR_95L_array', 'OR_95U_array', 'P_array', 'N_array']
# [array_check_prepare_tools] 开始按 SNPID 合并数据...
# ...

# %%
from array_check_prepare_tools import plot_wgs_array_beta_comparison
plot = plot_wgs_array_beta_comparison(
    merged_sumstat_file='/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/cteph_agp3k.array_wgs_compration.merged_sumstat.tsv',
    output_prefix="cteph_agp3k.array_wgs_compration",
    save_pdf=False,
)
# Out:
# [array_check_prepare_tools] 开始任务：绘制 WGS vs Array beta 值比较散点图
# [array_check_prepare_tools] 未指定 out_dir，默认输出到当前工作目录：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute
# [array_check_prepare_tools] 读取合并的 sumstat 文件：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/snippet_analysis/02.array_check_impute/cteph_agp3k.array_wgs_compration.merged_sumstat.tsv
# [array_check_prepare_tools] 使用分块读取优化内存使用
# [array_check_prepare_tools] 数据读取成功，行数：4940084
# [array_check_prepare_tools] 只保留必需列以优化内存，当前列数：4
# [array_check_prepare_tools] 优化数据类型以减少内存占用
# [array_check_prepare_tools] 计算相关系数
# [array_check_prepare_tools] 绘图数据统计：
# [array_check_prepare_tools]   有效变体数：4940084
# [array_check_prepare_tools]   WGS Beta 范围：[-2.6951, 2.5652]
# [array_check_prepare_tools]   Array Beta 范围：[-2.8902, 2.7585]
# [array_check_prepare_tools]   Pearson 相关系数：0.7700 (P = 0.00e+00)
# [array_check_prepare_tools] 开始绘制散点图（优化性能）
# ...
