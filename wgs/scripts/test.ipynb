# %%
import argparse
import pandas as pd
import sys
import os
import matplotlib.pyplot as plt

script_path = os.path.abspath('/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts')
if script_path not in sys.path:
    sys.path.append(script_path)

import importlib
import bbj_projection_tools

# 强制重新加载模块（适用于开发调试阶段）
importlib.reload(bbj_projection_tools)

from bbj_projection_tools import (
    plot_projection_pc1_pc2_and_select,
)

# %%
sscore_path = '/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/bbj_projection/03.bbj_projection/cteph_agp3k.bbj.projection.sscore'
case_prefix = 'PHOM'
case_name = 'CTEPH'
control_name = 'AGP3K'
prefix_out = 'cteph_agp3k'
rect_xlim = (-0.028, 0.016)
rect_ylim = (-0.024, 0.033)

# %%
from bbj_projection_tools import plot_projection_pc1_pc2_and_select

png_path, keep_path = plot_projection_pc1_pc2_and_select(
    sscore_path=sscore_path,
    case_prefix=case_prefix,
    case_name=case_name,
    control_name=control_name,
    prefix_out=prefix_out,
    # 可选：矩形范围
    rect_xlim=rect_xlim,
    rect_ylim=rect_ylim,
)
print("PNG:", png_path)
print("KEEP:", keep_path)
# Out:
# /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/bbj_projection_tools.py:896: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/bbj_projection_tools.py:1016: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# PNG: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/cteph_agp3k.bbj_projection.pc1_pc2.png
# KEEP: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/cteph_agp3k.bbj.projection.sample.keep.txt

# %%
import importlib
import bbj_projection_tools

# 强制重新加载模块（适用于开发调试阶段）
importlib.reload(bbj_projection_tools)

from bbj_projection_tools import (
    export_subset_bed,
)

# %%
bed_prefix = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/13.run_variant_qc/cteph_agp3k.sqc.vqc"
out_prefix = "cteph_agp3k.bbj.projection.subset"
threads = 16

# %%
subset_prefix = export_subset_bed(
    bed_prefix=bed_prefix,                  # 你的输入前缀
    keep_txt_path=keep_path,
    out_prefix=out_prefix,             # 可选
    threads=threads,
)
# Out:
# [BBJ-PREP 2025-08-19 16:16:24] 启动子集导出：bed_prefix=/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/13.run_variant_qc/cteph_agp3k.sqc.vqc, keep=/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/cteph_agp3k.bbj.projection.sample.keep.txt
# [BBJ-PREP 2025-08-19 16:16:24] 规范化 keep 样本清单（两列无表头）
# [BBJ-PREP 2025-08-19 16:16:24] 运行 plink2 --keep 导出子集
# [BBJ-PREP 2025-08-19 16:17:19] 子集导出完成，输出前缀：/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/cteph_agp3k.bbj.projection.subset
