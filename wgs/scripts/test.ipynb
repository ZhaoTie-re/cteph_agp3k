# %%
import argparse
import pandas as pd
import sys
import os
import matplotlib.pyplot as plt

script_path = os.path.abspath('/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts')
if script_path not in sys.path:
    sys.path.append(script_path)

import importlib
import pca_qc_tools

# 强制重新加载模块（适用于开发调试阶段）
importlib.reload(pca_qc_tools)

from pca_qc_tools import (
    run_prune_and_pca,
)

# %%
bed_prefix = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/13.run_variant_qc/cteph_agp3k.sqc.vqc"
high_ld = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/info/high-LD-regions-hg38-GRCh38.txt"
output_prefix = "cteph_agp3k"
threads = 16

# %%
no_high_ld_prefix, prune_in, prune_out, eigenvec_file, eigenval_file, eigenvec_allele_file = run_prune_and_pca(
    bed_prefix=bed_prefix,
    maf_threshold=0.05,
    high_ld=high_ld,
    threads=16,
    output_prefix="cteph_agp3k",
    plink2_path="/home/b/b37974/plink2",
)

# %%
import importlib
import pca_qc_tools

# 强制重新加载模块（适用于开发调试阶段）
importlib.reload(pca_qc_tools)

from pca_qc_tools import (
    plot_pca_pairwise_pdf,
)

# %%
pdf_path = plot_pca_pairwise_pdf(
    eigenvec_file=str(eigenvec),
    eigenval_file=str(eigenval),
    case_prefix="PHOM",   # 例如病例IID前缀
    case_name="CTEPH",
    control_name="AGP3K",
    output_pdf="pca_pairwise_plots.pdf"
)
# Out:
# /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/pca_qc_tools.py:193: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pca_df = pd.read_csv(eigenvec_path, delim_whitespace=True, header=None)
# /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/pca_qc_tools.py:211: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   pca_df = pca_df.iloc[:, : (2 + n_pcs)]  # 截断到一致的列数

# %%
import importlib
import pca_qc_tools

# 强制重新加载模块（适用于开发调试阶段）
importlib.reload(pca_qc_tools)

from pca_qc_tools import (
    prepare_bbj_genotype,
)

# %%
bbj_bed_prefix = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/BBJ_genome_b38/02.sample_qc/NewOE13_Auto.id.b38.sqc"
rename_chr = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/info/rename_chr.txt"
fasta_ref = "/LARGE0/gr10478/b37974/Pulmonary_Hypertension/nagasaki_pipeline/data/hs38DH.fa"

# %%
bbj_prepared_prefix = prepare_bbj_genotype(
    bbj_bed_prefix=bbj_bed_prefix,
    threads=32,
    rename_chr=rename_chr,
    fasta_ref=fasta_ref,
    maf=0.05,
)
# Out:
# [BBJ-PREP 2025-08-17 11:09:26] 启动 BBJ 基因型准备流程
# [BBJ-PREP 2025-08-17 11:09:26] 检测到 plink2: /home/b/b37974/plink2
# [BBJ-PREP 2025-08-17 11:09:26] 检测到 plink : /home/b/b37974/plink
# [BBJ-PREP 2025-08-17 11:09:26] 输入前缀就绪: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/BBJ_genome_b38/02.sample_qc/NewOE13_Auto.id.b38.sqc
# [BBJ-PREP 2025-08-17 11:09:26] 重命名表: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/info/rename_chr.txt
# [BBJ-PREP 2025-08-17 11:09:26] 参考序列: /LARGE0/gr10478/workspace/pipeline/data/hs38DH.fa
# [BBJ-PREP 2025-08-17 11:09:26] 最终输出前缀: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/bbj.b38.auto.sqc.vqc.rechr.norm.setid
# [BBJ-PREP 2025-08-17 11:09:26] 创建本地临时目录: /LARGE0/gr10478/b37974/Pulmonary_Hypertension/cteph_agp3k/wgs/scripts/bbj_prep_tmp/run_20250817_110926
# ...
